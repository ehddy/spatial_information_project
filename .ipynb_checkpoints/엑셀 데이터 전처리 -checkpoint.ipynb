# %%
import pandas as pd 
import numpy as np

# %%
# 분류표 데이터 불러오기 

# 윈도우
group_data =  pd.read_excel('C:/Users/Innovation/Desktop/김동요/프로젝트/매크로/2015_부문분류표.xlsx', usecols=[2, 3, 4, 5 ,6 ,7],skiprows=[0], sheet_name='상품분류표')

# %%
# 맥 
group_data =  pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_부문분류표.xlsx', usecols=[2, 3, 4, 5 ,6 ,7],skiprows=[0], sheet_name='상품분류표')

# %%
# 대분류 소분류 매칭 사전 생성 
def disting_small(data, small_name_count=None):
    data = data.iloc[1:]
    data.reset_index(drop=True, inplace=True)
    data.rename(columns={'Unnamed: 3':'소분류명', 'Unnamed: 5':'중분류명', 'Unnamed: 7':'대분류명'}, inplace=True)
    small_name = list(data['소분류명'].dropna(how=any))
    big_name = list(data['대분류명'].dropna(how=any))
    i = int(input('총 몇개의 대분류로 구성되어 있습니까? : '))
    dic = {}
    idx = 0
    yes_no = input('각 대분류의 포함된 소분류의 수를 이미 작성하신 리스트로 입력하겠습니까? \n 아니면, 직접 입력하겠습니까?(yes or no) ')         
            
    for k in range(i):
        if yes_no == 'yes':
            s = small_name_count[k]
        else:
            s = int(input('대분류 {}: {}에 포함된 소분류가 몇 개 입니까? '.format(k+1, big_name[k])))
            print()
        for j in range(idx, idx+s):
            idx += 1
            dic[small_name[j]] = big_name[k]
        print()
    print('완료')
    return dic, big_name


# 재분류 사전 생성 함수(소분류 수준)
def re_disting_small(dic, list_or_count=None, small_name_list=None):
    s = int(input('새로운 분류를 몇 개 추가할 것인가요? '))
    print()
    print()
    yes_or_no = input('이미 튜플 세트로 정리한 분류 이름과 개수 리스트가 있으신가요?(yes or no) ')
    print()
    yes_or_no2 = input('해당 분류에 속할 소분류 이름을 정리한 리스트가 있으신가요?(yes or no) ')        
    
    for i in range(s):
        if yes_or_no == 'yes':
            name = list_or_count[i][0]
            count_d = list_or_count[i][1]
        else:
            print('새로운 분류 이름과 해당 분류에 포함되는 소분류의 개수를 입력해주세요')
            name = input('새로운 분류 이름: ')
            count_d = int(input('{}에 포함될 소분류 개수: '.format(name)))
        print()
        for k in range(count_d):
            if yes_or_no2 == 'yes':
                small_name = small_name_list[i][k]
            else:
                small_name = input('{}에 포함될 {}번 째 소분류명을 입력해주세요 '.format(name, k+1))
            dic[small_name] = name 
        print(name, '분류 생성 완료')
        print()
    print('재분류 완료')
    return dic

# %%
# 각 대분류의 소분류 수 
small_name_count = [8, 4, 11, 6, 6, 3, 13, 5, 7, 4, 9, 6, 11, 7, 2, 1, 3, 4, 7, 1, 10, 2, 8, 4, 
                    3, 5, 4, 2, 1, 2, 2, 3, 1
                   ]

# %%
big_dict, big_name = disting_small(group_data, small_name_count)
# Out:
# /Users/dongyokim/miniforge3/envs/crawl/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# 총 몇개의 대분류로 구성되어 있습니까? : 33
# 각 대분류의 포함된 소분류의 수를 이미 작성하신 리스트로 입력하겠습니까?
#  아니면, 직접 입력하겠습니까?(yes or no) yes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 완료

# %% [markdown]
# ### 소분류 대분류 연결

# %%
big_dict
# Out:
# {'곡물 및 식량작물': '농림수산품',
#  '채소 및 과실': '농림수산품',
#  '기타작물': '농림수산품',
#  '낙농 및 축우': '농림수산품',
#  '기타 축산': '농림수산품',
#  '임산물': '농림수산품',
#  '수산물': '농림수산품',
#  '농림어업 서비스': '농림수산품',
#  '석탄': '광산품',
#  '원유 및 천연가스': '광산품',
#  '금속광물': '광산품',
#  '비금속광물': '광산품',
#  '육류 및 낙농품': '음식료품',
#  '수산가공품': '음식료품',
#  '정곡 및 제분': '음식료품',
#  '제당 및 전분': '음식료품',
#  '떡, 과자 및 면류': '음식료품',
#  '조미료 및 유지': '음식료품',
#  '기타 식료품': '음식료품',
#  '사료': '음식료품',
#  '주류': '음식료품',
#  '비알콜음료 및 얼음': '음식료품',
#  '담배': '음식료품',
#  '섬유사': '섬유 및 가죽제품',
#  '섬유직물': '섬유 및 가죽제품',
#  '섬유표백 및 염색 임가공': '섬유 및 가죽제품',
#  '직물제품': '섬유 및 가죽제품',
#  '의복제품': '섬유 및 가죽제품',
#  '가죽제품': '섬유 및 가죽제품',
#  '목재': '목재 및 종이, 인쇄',
#  '목제품': '목재 및 종이, 인쇄',
#  '펄프': '목재 및 종이, 인쇄',
#  '종이류': '목재 및 종이, 인쇄',
#  '종이제품': '목재 및 종이, 인쇄',
#  '인쇄 및 기록매체 복제': '목재 및 종이, 인쇄',
#  '석탄제품': '석탄 및 석유제품',
#  '원유정제처리제품': '석탄 및 석유제품',
#  '윤활유 및 기타석유정제품': '석탄 및 석유제품',
#  '기초유기화학물질': '화학제품',
#  '기초무기화학물질': '화학제품',
#  '합성수지 및 합성고무': '화학제품',
#  '화학섬유': '화학제품',
#  '의약품': '화학제품',
#  '비료 및 농약': '화학제품',
#  '도료 및 잉크': '화학제품',
#  '비누 및 화장품': '화학제품',
#  '기타 화학제품': '화학제품',
#  '플라스틱 1차제품': '화학제품',
#  '기타 플라스틱제품': '화학제품',
#  '타이어 및 튜브': '화학제품',
#  '기타 고무제품': '화학제품',
#  '유리 및 유리제품': '비금속광물제품',
#  '도자기 및 요업제품': '비금속광물제품',
#  '시멘트': '비금속광물제품',
#  '콘크리트제품': '비금속광물제품',
#  '기타 비금속광물제품': '비금속광물제품',
#  '선철 및 조강': '1차 금속제품',
#  '열간압연강재': '1차 금속제품',
#  '냉간압연강재': '1차 금속제품',
#  '기타 철강1차제품': '1차 금속제품',
#  '비철금속괴': '1차 금속제품',
#  '비철금속 1차제품': '1차 금속제품',
#  '금속 주물': '1차 금속제품',
#  '구조용 금속제품 및 탱크': '금속가공제품',
#  '금속 단조, 야금 및 압형제품': '금속가공제품',
#  '금속처리 및 가공품': '금속가공제품',
#  '기타 금속가공제품': '금속가공제품',
#  '반도체': '컴퓨터, 전자 및 광학기기',
#  '전자표시장치': '컴퓨터, 전자 및 광학기기',
#  '인쇄회로기판': '컴퓨터, 전자 및 광학기기',
#  '기타 전자부품': '컴퓨터, 전자 및 광학기기',
#  '컴퓨터 및 주변기기': '컴퓨터, 전자 및 광학기기',
#  '통신 및 방송장비': '컴퓨터, 전자 및 광학기기',
#  '영상 및 음향기기': '컴퓨터, 전자 및 광학기기',
#  '의료 및 측정기기': '컴퓨터, 전자 및 광학기기',
#  '기타 정밀기기': '컴퓨터, 전자 및 광학기기',
#  '발전기 및 전동기': '전기장비',
#  '전기변환.공급제어장치': '전기장비',
#  '전지': '전기장비',
#  '전선 및 케이블': '전기장비',
#  '가정용 전기기기': '전기장비',
#  '기타 전기장비': '전기장비',
#  '내연기관 및 터빈': '기계 및 장비',
#  '펌프 및 압축기': '기계 및 장비',
#  '일반목적용기계 부품': '기계 및 장비',
#  '산업용 운반기계': '기계 및 장비',
#  '공기 및 액체 조절장치': '기계 및 장비',
#  '기타 일반목적용기계': '기계 및 장비',
#  '농업 및 건설용 기계': '기계 및 장비',
#  '금속가공용 기계': '기계 및 장비',
#  '금형 및 주형': '기계 및 장비',
#  '반도체 및 디스플레이 제조용 기계': '기계 및 장비',
#  '기타 특수목적용기계': '기계 및 장비',
#  '자동차 ': '운송장비',
#  '특장차 및 트레일러': '운송장비',
#  '자동차 부품': '운송장비',
#  '선박': '운송장비',
#  '철도차량': '운송장비',
#  '항공기': '운송장비',
#  '기타 운송장비': '운송장비',
#  '가구': '기타 제조업 제품',
#  '기타 제조업 제품': '기타 제조업 제품',
#  '제조임가공 및 산업용 장비 수리': '제조임가공 및 산업용 장비 수리',
#  '전력 및 신재생에너지': '전력, 가스 및 증기',
#  '도시가스': '전력, 가스 및 증기',
#  '증기 및 온수 공급': '전력, 가스 및 증기',
#  '수도': '수도, 폐기물처리 및 재활용서비스',
#  '폐수처리': '수도, 폐기물처리 및 재활용서비스',
#  '폐기물처리': '수도, 폐기물처리 및 재활용서비스',
#  '자원재활용서비스': '수도, 폐기물처리 및 재활용서비스',
#  '주거용 건물': '건설',
#  '비주거용 건물': '건설',
#  '건축보수': '건설',
#  '교통시설 건설': '건설',
#  '일반토목시설 건설': '건설',
#  '산업시설 건설': '건설',
#  '기타 건설': '건설',
#  '도소매 및 상품중개서비스': '도소매 및 상품중개서비스',
#  '철도운송서비스': '운송서비스',
#  '도로운송서비스': '운송서비스',
#  '수상운송서비스': '운송서비스',
#  '항공운송서비스': '운송서비스',
#  '운송보조서비스': '운송서비스',
#  '하역서비스': '운송서비스',
#  '보관 및 창고서비스': '운송서비스',
#  '기타 운송 관련 서비스': '운송서비스',
#  '공영우편서비스': '운송서비스',
#  '소화물전문운송서비스': '운송서비스',
#  '음식점 및 주점': '음식점 및 숙박서비스',
#  '숙박서비스': '음식점 및 숙박서비스',
#  '유, 무선 및 위성 통신서비스': '정보통신 및 방송 서비스',
#  '기타 전기통신서비스': '정보통신 및 방송 서비스',
#  '방송서비스': '정보통신 및 방송 서비스',
#  '정보서비스': '정보통신 및 방송 서비스',
#  '소프트웨어 개발 공급': '정보통신 및 방송 서비스',
#  '기타 IT서비스': '정보통신 및 방송 서비스',
#  '신문 및 출판 서비스': '정보통신 및 방송 서비스',
#  '영상·오디오물 제작 배급': '정보통신 및 방송 서비스',
#  '중앙은행 및 예금취급기관': '금융 및 보험 서비스',
#  '기타 금융중개기관': '금융 및 보험 서비스',
#  '보험서비스': '금융 및 보험 서비스',
#  '금융 및 보험 보조 서비스': '금융 및 보험 서비스',
#  '주거서비스': '부동산서비스',
#  '비주거용 건물 임대 및 부동산 공급': '부동산서비스',
#  '부동산 관련 서비스': '부동산서비스',
#  '연구개발': '전문, 과학 및 기술 서비스',
#  '법무 및 경영지원 서비스': '전문, 과학 및 기술 서비스',
#  '광고': '전문, 과학 및 기술 서비스',
#  '건축·토목 관련 서비스': '전문, 과학 및 기술 서비스',
#  '기타 과학기술 및 전문 서비스': '전문, 과학 및 기술 서비스',
#  '장비·용품 및 지식재산권 임대': '사업지원서비스',
#  '사업시설 유지관리 및 조경서비스': '사업지원서비스',
#  '인력공급 및 알선': '사업지원서비스',
#  '기타 사업지원서비스': '사업지원서비스',
#  '공공행정 및 국방': '공공행정, 국방 및 사회보장',
#  '사회보험서비스': '공공행정, 국방 및 사회보장',
#  '교육서비스': '교육서비스',
#  '의료 및 보건': '보건 및 사회복지 서비스',
#  '사회복지서비스': '보건 및 사회복지 서비스',
#  '문화 및 여행 관련 서비스': '예술, 스포츠 및 여가 관련 서비스',
#  '스포츠 및 오락 서비스': '예술, 스포츠 및 여가 관련 서비스',
#  '사회단체': '기타 서비스',
#  '자동차 및 소비용품 수리서비스': '기타 서비스',
#  '개인서비스': '기타 서비스',
#  '기타': '기타'}

# %%
# 공간정보 교육서비스  +  협회 합한 버전 

# 새로 추가할 분류 이름과 해당 분류에 포함될 소분류 갯수 리스트 
new_big_list_or_count = [('공간정보 관련 제조업', 3), ('공간정보 관련 도매업', 1), ('공간정보 관련 출판 및 정보서비스업', 4),('공간정보 관련 기술서비스업', 2), ('공간정보 관련 협회 및 단체', 2)]

# 새로운 분류에 포함될 소분류 이름 리스트 
new_small_list = [['통신 및 방송장비', '의료 및 측정기기', '인쇄 및 기록매체 복제'], ['도소매 및 상품중개서비스'], ['소프트웨어 개발 공급', '기타 IT서비스', '정보서비스', '신문 및 출판 서비스'], ['건축·토목 관련 서비스', '기타 과학기술 및 전문 서비스'], ['사회단체', '교육서비스']]

# 마지막에 정렬할때 사용할 리스트 생성 
new_name = []
for i, count in new_big_list_or_count:
    new_name.append(i)

# %%
# 공간정보 합 x

# 새로 추가할 분류 이름과 해당 분류에 포함될 소분류 갯수 리스트 
new_big_list_or_count = [('공간정보 관련 제조업', 3), ('공간정보 관련 도매업', 1), ('공간정보 관련 출판 및 정보서비스업', 4),('공간정보 관련 기술서비스업', 2), ('공간정보 관련 교육서비스업', 1), ('공간정보 관련 협회 및 단체', 1)]

# 새로운 분류에 포함될 소분류 이름 리스트 
new_small_list = [['통신 및 방송장비', '의료 및 측정기기', '인쇄 및 기록매체 복제'], ['도소매 및 상품중개서비스'], ['소프트웨어 개발 공급', '기타 IT서비스', '정보서비스', '신문 및 출판 서비스'], ['건축·토목 관련 서비스', '기타 과학기술 및 전문 서비스'], ['교육서비스'], ['사회단체']]

# 마지막에 정렬할때 사용할 리스트 생성 
new_name = []
for i, count in new_big_list_or_count:
    new_name.append(i)

# %%
# 재분류표 생성 
new_big_dict = re_disting_small(big_dict, new_big_list_or_count, new_small_list)
# Out:
# 새로운 분류를 몇 개 추가할 것인가요? 5
#
#
# 이미 튜플 세트로 정리한 분류 이름과 개수 리스트가 있으신가요?(yes or no) yes
#
# 해당 분류에 속할 소분류 이름을 정리한 리스트가 있으신가요?(yes or no) yes
#
# 공간정보 관련 제조업 분류 생성 완료
#
#
# 공간정보 관련 도매업 분류 생성 완료
#
#
# 공간정보 관련 출판 및 정보서비스업 분류 생성 완료
#
#
# 공간정보 관련 기술서비스업 분류 생성 완료
#
#
# 공간정보 관련 협회 및 단체 분류 생성 완료
#
# 재분류 완료

# %%
# 소분류 수준에서 대분류로 재분류 완료 
new_big_dict
# Out:
# {'곡물 및 식량작물': '농림수산품',
#  '채소 및 과실': '농림수산품',
#  '기타작물': '농림수산품',
#  '낙농 및 축우': '농림수산품',
#  '기타 축산': '농림수산품',
#  '임산물': '농림수산품',
#  '수산물': '농림수산품',
#  '농림어업 서비스': '농림수산품',
#  '석탄': '광산품',
#  '원유 및 천연가스': '광산품',
#  '금속광물': '광산품',
#  '비금속광물': '광산품',
#  '육류 및 낙농품': '음식료품',
#  '수산가공품': '음식료품',
#  '정곡 및 제분': '음식료품',
#  '제당 및 전분': '음식료품',
#  '떡, 과자 및 면류': '음식료품',
#  '조미료 및 유지': '음식료품',
#  '기타 식료품': '음식료품',
#  '사료': '음식료품',
#  '주류': '음식료품',
#  '비알콜음료 및 얼음': '음식료품',
#  '담배': '음식료품',
#  '섬유사': '섬유 및 가죽제품',
#  '섬유직물': '섬유 및 가죽제품',
#  '섬유표백 및 염색 임가공': '섬유 및 가죽제품',
#  '직물제품': '섬유 및 가죽제품',
#  '의복제품': '섬유 및 가죽제품',
#  '가죽제품': '섬유 및 가죽제품',
#  '목재': '목재 및 종이, 인쇄',
#  '목제품': '목재 및 종이, 인쇄',
#  '펄프': '목재 및 종이, 인쇄',
#  '종이류': '목재 및 종이, 인쇄',
#  '종이제품': '목재 및 종이, 인쇄',
#  '인쇄 및 기록매체 복제': '공간정보 관련 제조업',
#  '석탄제품': '석탄 및 석유제품',
#  '원유정제처리제품': '석탄 및 석유제품',
#  '윤활유 및 기타석유정제품': '석탄 및 석유제품',
#  '기초유기화학물질': '화학제품',
#  '기초무기화학물질': '화학제품',
#  '합성수지 및 합성고무': '화학제품',
#  '화학섬유': '화학제품',
#  '의약품': '화학제품',
#  '비료 및 농약': '화학제품',
#  '도료 및 잉크': '화학제품',
#  '비누 및 화장품': '화학제품',
#  '기타 화학제품': '화학제품',
#  '플라스틱 1차제품': '화학제품',
#  '기타 플라스틱제품': '화학제품',
#  '타이어 및 튜브': '화학제품',
#  '기타 고무제품': '화학제품',
#  '유리 및 유리제품': '비금속광물제품',
#  '도자기 및 요업제품': '비금속광물제품',
#  '시멘트': '비금속광물제품',
#  '콘크리트제품': '비금속광물제품',
#  '기타 비금속광물제품': '비금속광물제품',
#  '선철 및 조강': '1차 금속제품',
#  '열간압연강재': '1차 금속제품',
#  '냉간압연강재': '1차 금속제품',
#  '기타 철강1차제품': '1차 금속제품',
#  '비철금속괴': '1차 금속제품',
#  '비철금속 1차제품': '1차 금속제품',
#  '금속 주물': '1차 금속제품',
#  '구조용 금속제품 및 탱크': '금속가공제품',
#  '금속 단조, 야금 및 압형제품': '금속가공제품',
#  '금속처리 및 가공품': '금속가공제품',
#  '기타 금속가공제품': '금속가공제품',
#  '반도체': '컴퓨터, 전자 및 광학기기',
#  '전자표시장치': '컴퓨터, 전자 및 광학기기',
#  '인쇄회로기판': '컴퓨터, 전자 및 광학기기',
#  '기타 전자부품': '컴퓨터, 전자 및 광학기기',
#  '컴퓨터 및 주변기기': '컴퓨터, 전자 및 광학기기',
#  '통신 및 방송장비': '공간정보 관련 제조업',
#  '영상 및 음향기기': '컴퓨터, 전자 및 광학기기',
#  '의료 및 측정기기': '공간정보 관련 제조업',
#  '기타 정밀기기': '컴퓨터, 전자 및 광학기기',
#  '발전기 및 전동기': '전기장비',
#  '전기변환.공급제어장치': '전기장비',
#  '전지': '전기장비',
#  '전선 및 케이블': '전기장비',
#  '가정용 전기기기': '전기장비',
#  '기타 전기장비': '전기장비',
#  '내연기관 및 터빈': '기계 및 장비',
#  '펌프 및 압축기': '기계 및 장비',
#  '일반목적용기계 부품': '기계 및 장비',
#  '산업용 운반기계': '기계 및 장비',
#  '공기 및 액체 조절장치': '기계 및 장비',
#  '기타 일반목적용기계': '기계 및 장비',
#  '농업 및 건설용 기계': '기계 및 장비',
#  '금속가공용 기계': '기계 및 장비',
#  '금형 및 주형': '기계 및 장비',
#  '반도체 및 디스플레이 제조용 기계': '기계 및 장비',
#  '기타 특수목적용기계': '기계 및 장비',
#  '자동차 ': '운송장비',
#  '특장차 및 트레일러': '운송장비',
#  '자동차 부품': '운송장비',
#  '선박': '운송장비',
#  '철도차량': '운송장비',
#  '항공기': '운송장비',
#  '기타 운송장비': '운송장비',
#  '가구': '기타 제조업 제품',
#  '기타 제조업 제품': '기타 제조업 제품',
#  '제조임가공 및 산업용 장비 수리': '제조임가공 및 산업용 장비 수리',
#  '전력 및 신재생에너지': '전력, 가스 및 증기',
#  '도시가스': '전력, 가스 및 증기',
#  '증기 및 온수 공급': '전력, 가스 및 증기',
#  '수도': '수도, 폐기물처리 및 재활용서비스',
#  '폐수처리': '수도, 폐기물처리 및 재활용서비스',
#  '폐기물처리': '수도, 폐기물처리 및 재활용서비스',
#  '자원재활용서비스': '수도, 폐기물처리 및 재활용서비스',
#  '주거용 건물': '건설',
#  '비주거용 건물': '건설',
#  '건축보수': '건설',
#  '교통시설 건설': '건설',
#  '일반토목시설 건설': '건설',
#  '산업시설 건설': '건설',
#  '기타 건설': '건설',
#  '도소매 및 상품중개서비스': '공간정보 관련 도매업',
#  '철도운송서비스': '운송서비스',
#  '도로운송서비스': '운송서비스',
#  '수상운송서비스': '운송서비스',
#  '항공운송서비스': '운송서비스',
#  '운송보조서비스': '운송서비스',
#  '하역서비스': '운송서비스',
#  '보관 및 창고서비스': '운송서비스',
#  '기타 운송 관련 서비스': '운송서비스',
#  '공영우편서비스': '운송서비스',
#  '소화물전문운송서비스': '운송서비스',
#  '음식점 및 주점': '음식점 및 숙박서비스',
#  '숙박서비스': '음식점 및 숙박서비스',
#  '유, 무선 및 위성 통신서비스': '정보통신 및 방송 서비스',
#  '기타 전기통신서비스': '정보통신 및 방송 서비스',
#  '방송서비스': '정보통신 및 방송 서비스',
#  '정보서비스': '공간정보 관련 출판 및 정보서비스업',
#  '소프트웨어 개발 공급': '공간정보 관련 출판 및 정보서비스업',
#  '기타 IT서비스': '공간정보 관련 출판 및 정보서비스업',
#  '신문 및 출판 서비스': '공간정보 관련 출판 및 정보서비스업',
#  '영상·오디오물 제작 배급': '정보통신 및 방송 서비스',
#  '중앙은행 및 예금취급기관': '금융 및 보험 서비스',
#  '기타 금융중개기관': '금융 및 보험 서비스',
#  '보험서비스': '금융 및 보험 서비스',
#  '금융 및 보험 보조 서비스': '금융 및 보험 서비스',
#  '주거서비스': '부동산서비스',
#  '비주거용 건물 임대 및 부동산 공급': '부동산서비스',
#  '부동산 관련 서비스': '부동산서비스',
#  '연구개발': '전문, 과학 및 기술 서비스',
#  '법무 및 경영지원 서비스': '전문, 과학 및 기술 서비스',
#  '광고': '전문, 과학 및 기술 서비스',
#  '건축·토목 관련 서비스': '공간정보 관련 기술서비스업',
#  '기타 과학기술 및 전문 서비스': '공간정보 관련 기술서비스업',
#  '장비·용품 및 지식재산권 임대': '사업지원서비스',
#  '사업시설 유지관리 및 조경서비스': '사업지원서비스',
#  '인력공급 및 알선': '사업지원서비스',
#  '기타 사업지원서비스': '사업지원서비스',
#  '공공행정 및 국방': '공공행정, 국방 및 사회보장',
#  '사회보험서비스': '공공행정, 국방 및 사회보장',
#  '교육서비스': '공간정보 관련 협회 및 단체',
#  '의료 및 보건': '보건 및 사회복지 서비스',
#  '사회복지서비스': '보건 및 사회복지 서비스',
#  '문화 및 여행 관련 서비스': '예술, 스포츠 및 여가 관련 서비스',
#  '스포츠 및 오락 서비스': '예술, 스포츠 및 여가 관련 서비스',
#  '사회단체': '공간정보 관련 협회 및 단체',
#  '자동차 및 소비용품 수리서비스': '기타 서비스',
#  '개인서비스': '기타 서비스',
#  '기타': '기타'}

# %%
# 소분류 데이터 불러오기 

# 윈도우 
small_data_2015 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/프로젝트/매크로/2019_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])

# %%
# 맥 

# 총 거래표(소분류 수준) 
small_data_2015 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2016 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2017 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2018 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2019 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])





# 국산거래표(소분류 수준) 
small_data_2015_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2016_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2017_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2018_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2019_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])

# %%
 # 재분류 열 추가 생성 함수(대분류 수준)
def dic_pre(x, dic):
    try:
        return dic[x]
    except:
        return 0

# %%
# 자동 부분합 함수(대분류 수준)
def groupping(data, dic, disting_standard, metrix_count):
    
    
    data = data.iloc[:, 1:]
    data.rename(columns={'Unnamed: 1':'상품분류'}, inplace=True)
    data.set_index('상품분류', inplace=True)
    
    data['대분류'] = list(pd.Series(data.index.values).apply(lambda x: dic_pre(x, dic)))

    data = data.replace(0, np.NaN)

    metrix_a_1 = data.loc[:'중간투입계', :].groupby('대분류').sum()
    metrix_b_1 = data.loc['중간투입계':, :]

    big_name_list_index = disting_standard[:metrix_count]
    big_name_list_index.extend(new_name)
    big_name_list_index.extend(list(metrix_b_1.index))
    
    metrix_total_1 = pd.concat([metrix_a_1, metrix_b_1], axis=0).transpose()


    metrix_total_1['대분류'] = list(pd.Series(metrix_total_1.index.values).apply(lambda x: dic_pre(x, dic)))
    metrix_total_1 = metrix_total_1.replace(0, np.NaN)

    metrix_a_2 = metrix_total_1.loc[:'중간수요계', :].groupby('대분류').sum()
    metrix_b_2 = metrix_total_1.loc['중간수요계':, :]
    
    big_name_list_columns = disting_standard[:metrix_count]
    big_name_list_columns.extend(new_name)
    big_name = big_name_list_columns.copy()
    big_name_list_columns.extend(list(metrix_b_2.index))
    
    big_name_list_columns = big_name_list_columns[:-1]



    metrix_total_2 = pd.concat([metrix_a_2, metrix_b_2], axis=0).transpose()

    metrix_total_2.drop('대분류', axis=0, inplace=True)
    metrix_total_2.drop('대분류', axis=1, inplace=True)
    
    metrix_total_2 = metrix_total_2.reindex(index=big_name_list_index, columns=big_name_list_columns)
    
    return metrix_total_2, big_name

# %%
# 총 거래표 
big_data_2015, big_name_2015  = groupping(small_data_2015, new_big_dict, big_name, 33)
big_data_2016, big_name_2016  = groupping(small_data_2016, new_big_dict, big_name, 33)
big_data_2017, big_name_2017  = groupping(small_data_2017, new_big_dict, big_name, 33)
big_data_2018, big_name_2018  = groupping(small_data_2018, new_big_dict, big_name, 33)
big_data_2019, big_name_2019  = groupping(small_data_2019, new_big_dict, big_name, 33)

total_big_data = [big_data_2015, big_data_2016, big_data_2017, big_data_2018, big_data_2019]
# 음식료품                    81680.0     81573.0  ...    69007454.0
# 섬유 및 가죽제품              233705.0    387271.0  ...    27380638.0
# 목재 및 종이, 인쇄            265933.0    692682.0  ...    28575874.0
# 석탄 및 석유제품              563298.0    476520.0  ...    56072785.0
# 화학제품                  1389216.0   4665753.0  ...   160777739.0
# 비금속광물제품               2084451.0    407646.0  ...    36806558.0
# 1차 금속제품              23471006.0  15701862.0  ...    89603359.0
# 금속가공제품                1112580.0  13210766.0  ...    81850313.0
# 컴퓨터, 전자 및 광학기기          38769.0    121645.0  ...    55615981.0
# 전기장비                   238905.0    602162.0  ...    53672585.0
# 기계 및 장비                951360.0   2676111.0  ...    43788085.0
# 운송장비                   113421.0    182258.0  ...    79814650.0
# 기타 제조업 제품               15893.0     31447.0  ...    10471131.0
# 제조임가공 및 산업용 장비 수리     2421888.0   3858282.0  ...    58389106.0
# 전력, 가스 및 증기           6854752.0   1899921.0  ...    74991997.0
# 수도, 폐기물처리 및 재활용서비스    2766249.0    406784.0  ...    14272030.0
# 건설                     144408.0     95193.0  ...    11398431.0
# 도소매 및 상품중개서비스               NaN         NaN  ...           NaN
# 운송서비스                 3669795.0   2247398.0  ...    83373986.0
# 음식점 및 숙박서비스            777199.0    869663.0  ...    53730327.0
# 정보통신 및 방송 서비스          160193.0    267086.0  ...    39616281.0
# 금융 및 보험 서비스           1496106.0   1344315.0  ...    89235298.0
# 부동산서비스                 366262.0    260213.0  ...    50853557.0
# 전문, 과학 및 기술 서비스       2603249.0   1396141.0  ...    66387211.0
# 사업지원서비스               1052703.0    683147.0  ...    64141070.0
# 공공행정, 국방 및 사회보장             0.0         0.0  ...     2152392.0
# 교육서비스                       NaN         NaN  ...           NaN
# 보건 및 사회복지 서비스          134160.0    189313.0  ...     7139172.0
# 예술, 스포츠 및 여가 관련 서비스    162540.0    147242.0  ...     7354547.0
# 기타 서비스                 121456.0    163593.0  ...     9892841.0
# 기타                      87686.0    113915.0  ...     4144010.0
# 공간정보 관련 제조업            294136.0    451365.0  ...    32704752.0
# 공간정보 관련 도매업           2495930.0   3035447.0  ...   131233479.0
# 공간정보 관련 출판 및 정보서비스업    274335.0    192283.0  ...    31650287.0
# 공간정보 관련 기술서비스업        1267668.0    754127.0  ...    37961311.0
# 공간정보 관련 협회 및 단체        195859.0    159929.0  ...     5920037.0
# 중간투입계                58208193.0  57809356.0  ...  1718868915.0
#
#                     민간소비지출\n(가계 및 가계봉사\n비영리단체)       정부소비지출   민간고정\n자본형성  \
# 농림수산품                               14150710.0          NaN     392372.0
# 광산품                                     3972.0          NaN          NaN
# 음식료품                                45705216.0          NaN          NaN
# 섬유 및 가죽제품                           16641521.0          NaN      79953.0
# 목재 및 종이, 인쇄                           841596.0          NaN          NaN
# 석탄 및 석유제품                           13444272.0          NaN          NaN
# 화학제품                                 3169798.0          NaN          NaN
# 비금속광물제품                                14054.0          NaN          NaN
# 1차 금속제품                              -563598.0          NaN   -2448262.0
# 금속가공제품                                704425.0          NaN    3552411.0
# 컴퓨터, 전자 및 광학기기                       6059148.0          NaN    5530179.0
# 전기장비                                 3941220.0          NaN    7869558.0
# 총 거래표 열 및 행 제거 
for data in total_big_data:
    data.drop(['도소매 및 상품중개서비스', '교육서비스'], axis=0, inplace=True)
    data.drop(['도소매 및 상품중개서비스', '교육서비스'], axis=1, inplace=True)


for data in total_big_data2:
    data.drop(['도소매 및 상품중개서비스', '교육서비스'], axis=0, inplace=True)
    data.drop(['도소매 및 상품중개서비스', '교육서비스'], axis=1, inplace=True)

# %%
big_name.remove('도소매 및 상품중개서비스')
big_name.remove('교육서비스')

# %%
# 데이터 저장
year = 2015
for data in total_big_data:
    data.to_excel('{}년 총거래표(36)_2022.08_18.xlsx'.format(year))
    year += 1 

year -= 5
    
for data in total_big_data2:
    data.to_excel('{}년 국산거래표(36)_2022.08_18.xlsx'.format(year))
    year += 1 
    
print('저장 완료')
# Out:
# 저장 완료

# %%
big_name
# Out:
# ['농림수산품',
#  '광산품',
#  '음식료품',
#  '섬유 및 가죽제품',
#  '목재 및 종이, 인쇄',
#  '석탄 및 석유제품',
#  '화학제품',
#  '비금속광물제품',
#  '1차 금속제품',
#  '금속가공제품',
#  '컴퓨터, 전자 및 광학기기',
#  '전기장비',
#  '기계 및 장비',
#  '운송장비',
#  '기타 제조업 제품',
#  '제조임가공 및 산업용 장비 수리',
#  '전력, 가스 및 증기',
#  '수도, 폐기물처리 및 재활용서비스',
#  '건설',
#  '운송서비스',
#  '음식점 및 숙박서비스',
#  '정보통신 및 방송 서비스',
#  '금융 및 보험 서비스',
#  '부동산서비스',
#  '전문, 과학 및 기술 서비스',
#  '사업지원서비스',
#  '공공행정, 국방 및 사회보장',
#  '보건 및 사회복지 서비스',
#  '예술, 스포츠 및 여가 관련 서비스',
#  '기타 서비스',
#  '기타',
#  '공간정보 관련 제조업',
#  '공간정보 관련 도매업',
#  '공간정보 관련 출판 및 정보서비스업',
#  '공간정보 관련 기술서비스업',
#  '공간정보 관련 협회 및 단체']

# %%
five_name
# Out:
# ['농림수산광업',
#  '제조업',
#  'SOC 산업',
#  '서비스업',
#  '공간정보 관련 제조업',
#  '공간정보 관련 도매업',
#  '공간정보 관련 출판 및 정보서비스업',
#  '공간정보 관련 기술서비스업',
#  '공간정보 관련 협회 및 단체']

# %%
five_name_count = [2, 14, 3, 12, 1, 1, 1, 1, 1]

# %%
# 각 최종분류의 대분류 수 (합 x)
five_name_count = [2, 14, 3, 12, 6]

# %%
# 각 최종분류의 이름 및 개수 
twenty_name_count = [('농림수산광업', 2), ('전기, 가스 수도사업', 2), ('건설업', 1), ('음식료품제조업', 1), ('코크스 및 석유정제품 제조업', 1), ('화학물질 및 화학제품 제조업', 1), ('공간정보외 기기 및 용품 제조업', 1), ('전기장비 제조업', 1), 
               ('운송장비 제조업', 1), ('제조업', 8), ('운수업', 1), ('숙박 및 음식점업', 1), ('공간정보외 정보통신업', 1), ('금융 및 보험업', 1),
               ('부동산업', 1), ('공간정보외 전문, 과학 및 기술관련 서비스업', 1), ('사업 지원 서비스업', 1), ('의료, 보건업 및 사회복지서비스업', 1), ('서비스업', 4), ('공간정보산업', 5)]
                   '공간정보 관련 협회 및 단체']]

new_twentyfive_list = [['농림수산품', '광산품'], ['전력, 가스 및 증기', '수도, 폐기물처리 및 재활용서비스'], ['건설'], 
                  ['음식료품'], ['석탄 및 석유제품'], ['화학제품'], ['컴퓨터, 전자 및 광학기기'], ['전기장비'], ['운송장비'], 
                  ['섬유 및 가죽제품', '목재 및 종이, 인쇄', '비금속광물제품', '1차 금속제품', '금속가공제품', '기계 및 장비', '기타 제조업 제품', '제조임가공 및 산업용 장비 수리'], 
                  ['운송서비스'], ['음식점 및 숙박서비스'], ['정보통신 및 방송 서비스'], ['금융 및 보험 서비스'], ['부동산서비스'], 
                  ['전문, 과학 및 기술 서비스'], ['사업지원서비스'], ['보건 및 사회복지 서비스'], ['공공행정, 국방 및 사회보장', '예술, 스포츠 및 여가 관련 서비스', '기타 서비스', '기타'], 
                  ['공간정보 관련 제조업'], ['공간정보 관련 도매업'], ['공간정보 관련 출판 및 정보서비스업'], ['공간정보 관련 기술서비스업'], 
                   ['공간정보 관련 협회 및 단체']]

# %%
# 대분류 최종분류 매칭 사전 생성 (분류표가 이미 정렬되어 있는 경우)
def disting_big(big_name_data, final_name, big_name_count=None):
    i = int(input('총 몇개의 최종분류로 구성되어 있습니까? : '))
    dic = {}
    idx = 0
    yes_no = input('각 최종분류의 포함된 대분류의 수를 이미 작성하신 리스트로 입력하겠습니까? \n 아니면, 직접 입력하겠습니까?(yes or no) ')         
          
    for k in range(i):
        if yes_no == 'yes':
            s = big_name_count[k]
        else:
            s = int(input('최종분류 {}: {}에 포함된 대분류가 몇 개 입니까? '.format(k+1, final_name[k])))
            print()
        for j in range(idx, idx+s):
            idx += 1
            dic[big_name_data[j]] = final_name[k]
        print()
    print('완료')
    return dic

# 재분류 사전 생성 함수(소분류 수준)
def re_disting_big(dic, list_or_count=None, big_name_list=None):
    s = int(input('새로운 분류를 몇 개 추가할 것인가요? '))
    print()
    print()
    yes_or_no = input('이미 튜플 세트로 정리한 분류 이름과 개수 리스트가 있으신가요?(yes or no) ')
    print()
    yes_or_no2 = input('해당 분류에 속할 소분류 이름을 정리한 리스트가 있으신가요?(yes or no) ')        
    
    for i in range(s):
        if yes_or_no == 'yes':
            name = list_or_count[i][0]
            count_d = list_or_count[i][1]
        else:
            print('새로운 분류 이름과 해당 분류에 포함되는 소분류의 개수를 입력해주세요')
            name = input('새로운 분류 이름: ')
            count_d = int(input('{}에 포함될 소분류 개수: '.format(name)))
        print()
        for k in range(count_d):
            if yes_or_no2 == 'yes':
                small_name = big_name_list[i][k]
            else:
                small_name = input('{}에 포함될 {}번 째 소분류명을 입력해주세요 '.format(name, k+1))
            dic[small_name] = name 
        print(name, '분류 생성 완료')
        print()
    print('재분류 완료')
    return dic

# %%
five_dict = disting_big(big_name, five_name, five_name_count)
# Out:
# 총 몇개의 최종분류로 구성되어 있습니까? : 9
# 각 최종분류의 포함된 대분류의 수를 이미 작성하신 리스트로 입력하겠습니까?
#  아니면, 직접 입력하겠습니까?(yes or no) yes
#
#
#
#
#
#
#
#
#
# 완료

# %%
five_dict
# Out:
# {'농림수산품': '농림수산광업',
#  '광산품': '농림수산광업',
#  '음식료품': '제조업',
#  '섬유 및 가죽제품': '제조업',
#  '목재 및 종이, 인쇄': '제조업',
#  '석탄 및 석유제품': '제조업',
#  '화학제품': '제조업',
#  '비금속광물제품': '제조업',
#  '1차 금속제품': '제조업',
#  '금속가공제품': '제조업',
#  '컴퓨터, 전자 및 광학기기': '제조업',
#  '전기장비': '제조업',
#  '기계 및 장비': '제조업',
#  '운송장비': '제조업',
#  '기타 제조업 제품': '제조업',
#  '제조임가공 및 산업용 장비 수리': '제조업',
#  '전력, 가스 및 증기': 'SOC 산업',
#  '수도, 폐기물처리 및 재활용서비스': 'SOC 산업',
#  '건설': 'SOC 산업',
#  '운송서비스': '서비스업',
#  '음식점 및 숙박서비스': '서비스업',
#  '정보통신 및 방송 서비스': '서비스업',
#  '금융 및 보험 서비스': '서비스업',
#  '부동산서비스': '서비스업',
#  '전문, 과학 및 기술 서비스': '서비스업',
#  '사업지원서비스': '서비스업',
#  '공공행정, 국방 및 사회보장': '서비스업',
#  '보건 및 사회복지 서비스': '서비스업',
#  '예술, 스포츠 및 여가 관련 서비스': '서비스업',
#  '기타 서비스': '서비스업',
#  '기타': '서비스업',
#  '공간정보 관련 제조업': '공간정보 관련 제조업',
#  '공간정보 관련 도매업': '공간정보 관련 도매업',
#  '공간정보 관련 출판 및 정보서비스업': '공간정보 관련 출판 및 정보서비스업',
#  '공간정보 관련 기술서비스업': '공간정보 관련 기술서비스업',
#  '공간정보 관련 협회 및 단체': '공간정보 관련 협회 및 단체'}

# %%
twenty_dict = re_disting_big(five_dict.copy(), twenty_name_count, new_twenty_list)
# Out:
# 새로운 분류를 몇 개 추가할 것인가요? 20
#
#
# 이미 튜플 세트로 정리한 분류 이름과 개수 리스트가 있으신가요?(yes or no) yes
#
# 해당 분류에 속할 소분류 이름을 정리한 리스트가 있으신가요?(yes or no) yes
#
# 농림수산광업 분류 생성 완료
#
#
# 전기, 가스 수도사업 분류 생성 완료
#
#
# 건설업 분류 생성 완료
#
#
# 음식료품제조업 분류 생성 완료
#
#
# 코크스 및 석유정제품 제조업 분류 생성 완료
#
#
# 화학물질 및 화학제품 제조업 분류 생성 완료
#
#
# 공간정보외 기기 및 용품 제조업 분류 생성 완료
#
#
# 전기장비 제조업 분류 생성 완료
#
#
# 운송장비 제조업 분류 생성 완료
#
#
# 제조업 분류 생성 완료
#
#
# 운수업 분류 생성 완료
#
#
# 숙박 및 음식점업 분류 생성 완료
#
#
# 공간정보외 정보통신업 분류 생성 완료
#
#
# 금융 및 보험업 분류 생성 완료
#
#
# 부동산업 분류 생성 완료
#
#
# 공간정보외 전문, 과학 및 기술관련 서비스업 분류 생성 완료
#
#
# 사업 지원 서비스업 분류 생성 완료
#
#
# 의료, 보건업 및 사회복지서비스업 분류 생성 완료
#
#
# 서비스업 분류 생성 완료
#
#
# 공간정보산업 분류 생성 완료
#
# 재분류 완료

# %%
twenty_dict
# Out:
# {'농림수산품': '농림수산광업',
#  '광산품': '농림수산광업',
#  '음식료품': '음식료품제조업',
#  '섬유 및 가죽제품': '제조업',
#  '목재 및 종이, 인쇄': '제조업',
#  '석탄 및 석유제품': '코크스 및 석유정제품 제조업',
#  '화학제품': '화학물질 및 화학제품 제조업',
#  '비금속광물제품': '제조업',
#  '1차 금속제품': '제조업',
#  '금속가공제품': '제조업',
#  '컴퓨터, 전자 및 광학기기': '공간정보외 기기 및 용품 제조업',
#  '전기장비': '전기장비 제조업',
#  '기계 및 장비': '제조업',
#  '운송장비': '운송장비 제조업',
#  '기타 제조업 제품': '제조업',
#  '제조임가공 및 산업용 장비 수리': '제조업',
#  '전력, 가스 및 증기': '전기, 가스 수도사업',
#  '수도, 폐기물처리 및 재활용서비스': '전기, 가스 수도사업',
#  '건설': '건설업',
#  '운송서비스': '운수업',
#  '음식점 및 숙박서비스': '숙박 및 음식점업',
#  '정보통신 및 방송 서비스': '공간정보외 정보통신업',
#  '금융 및 보험 서비스': '금융 및 보험업',
#  '부동산서비스': '부동산업',
#  '전문, 과학 및 기술 서비스': '공간정보외 전문, 과학 및 기술관련 서비스업',
#  '사업지원서비스': '사업 지원 서비스업',
#  '공공행정, 국방 및 사회보장': '서비스업',
#  '보건 및 사회복지 서비스': '의료, 보건업 및 사회복지서비스업',
#  '예술, 스포츠 및 여가 관련 서비스': '서비스업',
#  '기타 서비스': '서비스업',
#  '기타': '서비스업',
#  '공간정보 관련 제조업': '공간정보산업',
#  '공간정보 관련 도매업': '공간정보산업',
#  '공간정보 관련 출판 및 정보서비스업': '공간정보산업',
#  '공간정보 관련 기술서비스업': '공간정보산업',
#  '공간정보 관련 협회 및 단체': '공간정보산업'}

# %%
twenty_five_dict = re_disting_big(five_dict.copy(), twentyfive_name_count, new_twentyfive_list)
# Out:
# 새로운 분류를 몇 개 추가할 것인가요? 24
#
#
# 이미 튜플 세트로 정리한 분류 이름과 개수 리스트가 있으신가요?(yes or no) yes
#
# 해당 분류에 속할 소분류 이름을 정리한 리스트가 있으신가요?(yes or no) yes
#
# 농림수산광업 분류 생성 완료
#
#
# 전기, 가스 수도사업 분류 생성 완료
#
#
# 건설업 분류 생성 완료
#
#
# 음식료품제조업 분류 생성 완료
#
#
# 코크스 및 석유정제품 제조업 분류 생성 완료
#
#
# 화학물질 및 화학제품 제조업 분류 생성 완료
#
#
# 공간정보외 기기 및 용품 제조업 분류 생성 완료
#
#
# 전기장비 제조업 분류 생성 완료
#
#
# 운송장비 제조업 분류 생성 완료
#
#
# 제조업 분류 생성 완료
#
#
# 운수업 분류 생성 완료
#
#
# 숙박 및 음식점업 분류 생성 완료
#
#
# 공간정보외 정보통신업 분류 생성 완료
#
#
# 금융 및 보험업 분류 생성 완료
#
#
# 부동산업 분류 생성 완료
#
#
# 공간정보외 전문, 과학 및 기술관련 서비스업 분류 생성 완료
#
#
# 사업 지원 서비스업 분류 생성 완료
#
#
# 의료, 보건업 및 사회복지서비스업 분류 생성 완료
#
#
# 서비스업 분류 생성 완료
#
#
# 공간정보 관련 제조업 분류 생성 완료
#
#
# 공간정보 관련 도매업 분류 생성 완료
#
#
# 공간정보 관련 출판 및 정보서비스업 분류 생성 완료
#
#
# 공간정보 관련 기술서비스업 분류 생성 완료
#
#
# 공간정보 관련 협회 및 단체 분류 생성 완료
#
# 재분류 완료

# %%
twenty_five_dict
# Out:
# {'농림수산품': '농림수산광업',
#  '광산품': '농림수산광업',
#  '음식료품': '음식료품제조업',
#  '섬유 및 가죽제품': '제조업',
#  '목재 및 종이, 인쇄': '제조업',
#  '석탄 및 석유제품': '코크스 및 석유정제품 제조업',
#  '화학제품': '화학물질 및 화학제품 제조업',
#  '비금속광물제품': '제조업',
#  '1차 금속제품': '제조업',
#  '금속가공제품': '제조업',
#  '컴퓨터, 전자 및 광학기기': '공간정보외 기기 및 용품 제조업',
#  '전기장비': '전기장비 제조업',
#  '기계 및 장비': '제조업',
#  '운송장비': '운송장비 제조업',
#  '기타 제조업 제품': '제조업',
#  '제조임가공 및 산업용 장비 수리': '제조업',
#  '전력, 가스 및 증기': '전기, 가스 수도사업',
#  '수도, 폐기물처리 및 재활용서비스': '전기, 가스 수도사업',
#  '건설': '건설업',
#  '운송서비스': '운수업',
#  '음식점 및 숙박서비스': '숙박 및 음식점업',
#  '정보통신 및 방송 서비스': '공간정보외 정보통신업',
#  '금융 및 보험 서비스': '금융 및 보험업',
#  '부동산서비스': '부동산업',
#  '전문, 과학 및 기술 서비스': '공간정보외 전문, 과학 및 기술관련 서비스업',
#  '사업지원서비스': '사업 지원 서비스업',
#  '공공행정, 국방 및 사회보장': '서비스업',
#  '보건 및 사회복지 서비스': '의료, 보건업 및 사회복지서비스업',
#  '예술, 스포츠 및 여가 관련 서비스': '서비스업',
#  '기타 서비스': '서비스업',
#  '기타': '서비스업',
#  '공간정보 관련 제조업': '공간정보 관련 제조업',
#  '공간정보 관련 도매업': '공간정보 관련 도매업',
#  '공간정보 관련 출판 및 정보서비스업': '공간정보 관련 출판 및 정보서비스업',
#  '공간정보 관련 기술서비스업': '공간정보 관련 기술서비스업',
#  '공간정보 관련 협회 및 단체': '공간정보 관련 협회 및 단체'}

# %%
def groupping_final(data, dic, disting_standard, metrix_count):
    
    data['대분류'] = list(pd.Series(data.index.values).apply(lambda x: dic_pre(x, dic)))

    data = data.replace(0, np.NaN)

    metrix_a_1 = data.loc[:'중간투입계', :].groupby('대분류').sum()
    metrix_b_1 = data.loc['중간투입계':, :]

    big_name_list_index = disting_standard[:metrix_count]
    big_name_list_index.extend(list(metrix_b_1.index))
    
    metrix_total_1 = pd.concat([metrix_a_1, metrix_b_1], axis=0).transpose()


    metrix_total_1['대분류'] = list(pd.Series(metrix_total_1.index.values).apply(lambda x: dic_pre(x, dic)))
    metrix_total_1 = metrix_total_1.replace(0, np.NaN)

    metrix_a_2 = metrix_total_1.loc[:'중간수요계', :].groupby('대분류').sum()
    metrix_b_2 = metrix_total_1.loc['중간수요계':, :]
    
    big_name_list_columns = disting_standard[:metrix_count]
    big_name = big_name_list_columns.copy()
    big_name_list_columns.extend(list(metrix_b_2.index))
    
    big_name_list_columns = big_name_list_columns[:-1]



    metrix_total_2 = pd.concat([metrix_a_2, metrix_b_2], axis=0).transpose()

    metrix_total_2.drop('대분류', axis=0, inplace=True)
    metrix_total_2.drop('대분류', axis=1, inplace=True)
    
    metrix_total_2 = metrix_total_2.reindex(index=big_name_list_index, columns=big_name_list_columns)
    
    return metrix_total_2, big_name

# %%
# 총거래표 
final_five_data_2015, final_five_name = groupping_final(big_data_2015, five_dict, five_name, 9)
final_five_data_2016, final_five_name = groupping_final(big_data_2016, five_dict, five_name, 9)
final_five_data_2017, final_five_name = groupping_final(big_data_2017, five_dict, five_name, 9)
final_five_data_2018, final_five_name = groupping_final(big_data_2018, five_dict, five_name, 9)
final_five_data_2019, final_five_name = groupping_final(big_data_2019, five_dict, five_name, 9)

total_five_data = [final_five_data_2015, final_five_data_2016, final_five_data_2017, final_five_data_2018, final_five_data_2019]

final_twenty_data_2015, final_twenty_name = groupping_final(big_data_2015, twenty_dict, twenty_name, 20)
final_twenty_data_2016, final_twenty_name = groupping_final(big_data_2016, twenty_dict, twenty_name, 20)
final_twenty_data_2017, final_twenty_name = groupping_final(big_data_2017, twenty_dict, twenty_name, 20)
final_twenty_data_2018, final_twenty_name = groupping_final(big_data_2018, twenty_dict, twenty_name, 20)
final_twenty_data_2019, final_twenty_name = groupping_final(big_data_2019, twenty_dict, twenty_name, 20)

total_twenty_data = [final_twenty_data_2015, final_twenty_data_2016, final_twenty_data_2017, final_twenty_data_2018, final_twenty_data_2019]

final_twentyfive_data_2015, final_twentyfive_name = groupping_final(big_data_2015, twenty_five_dict, twentyfive_name, 24)
final_twentyfive_data_2016, final_twentyfive_name = groupping_final(big_data_2016, twenty_five_dict, twentyfive_name, 24)
final_twentyfive_data_2017, final_twentyfive_name = groupping_final(big_data_2017, twenty_five_dict, twentyfive_name, 24)
final_twentyfive_data_2018, final_twentyfive_name = groupping_final(big_data_2018, twenty_five_dict, twentyfive_name, 24)
final_twentyfive_data_2019, final_twentyfive_name = groupping_final(big_data_2019, twenty_five_dict, twentyfive_name, 24)

total_twentyfive_data = [final_twentyfive_data_2015, final_twentyfive_data_2016, final_twentyfive_data_2017, final_twentyfive_data_2018, final_twentyfive_data_2019]

# 국산거래표 

final_five_data_2015_2, final_five_name = groupping_final(big_data_2015_2, five_dict, five_name, 9)
final_five_data_2016_2, final_five_name = groupping_final(big_data_2016_2, five_dict, five_name, 9)
final_five_data_2017_2, final_five_name = groupping_final(big_data_2017_2, five_dict, five_name, 9)
final_five_data_2018_2, final_five_name = groupping_final(big_data_2018_2, five_dict, five_name, 9)
final_five_data_2019_2, final_five_name = groupping_final(big_data_2019_2, five_dict, five_name, 9)

total_five_data_2 = [final_five_data_2015_2, final_five_data_2016_2, final_five_data_2017_2, final_five_data_2018_2, final_five_data_2019_2]

final_twenty_data_2015_2, final_twenty_name = groupping_final(big_data_2015_2, twenty_dict, twenty_name, 20)
final_twenty_data_2016_2, final_twenty_name = groupping_final(big_data_2016_2, twenty_dict, twenty_name, 20)
final_twenty_data_2017_2, final_twenty_name = groupping_final(big_data_2017_2, twenty_dict, twenty_name, 20)
final_twenty_data_2018_2, final_twenty_name = groupping_final(big_data_2018_2, twenty_dict, twenty_name, 20)
# 공간정보 관련 협회 및 단체           127638.0        629587.0     5920037.0
# 중간투입계                   12360802.0      41716622.0  1718868915.0
#
#                     민간소비지출\n(가계 및 가계봉사\n비영리단체)       정부소비지출   민간고정\n자본형성  \
# 농림수산광업                              14154682.0          NaN     392372.0
# 제조업                                118422939.0          NaN   64333266.0
# SOC 산업                              21092165.0    1165711.0  165908820.0
# 서비스업                               400520437.0  188635207.0   81212847.0
# 공간정보 관련 제조업                         10711145.0          NaN    4071340.0
# 공간정보 관련 도매업                         78971850.0          NaN   11056000.0
# 공간정보 관련 출판 및 정보서비스업                 11718726.0          NaN   25925140.0
# 공간정보 관련 기술서비스업                       1517477.0          NaN     350421.0
# 공간정보 관련 협회 및 단체                     63202595.0   60287050.0          NaN
# 중간투입계                              720312016.0  250087968.0  353250206.0
#
#                      정부고정\n자본형성       재고증감   귀중품\n순취득           수출  \
# 농림수산광업                  15171.0  1228748.0        NaN     816327.0
# 제조업                   8997637.0  3621766.0  1043186.0  566453810.0
# SOC 산업               47566824.0 -1422185.0        NaN     664771.0
# 서비스업                  9759127.0    81459.0    10391.0   72403690.0
# 공간정보 관련 제조업           1375882.0  1437166.0        NaN   42029301.0
# 공간정보 관련 도매업            707083.0  1227459.0   318400.0   24133371.0
# 공간정보 관련 출판 및 정보서비스업    232113.0    17467.0        NaN    4056463.0
# 공간정보 관련 기술서비스업              NaN        NaN        NaN    4085775.0
# 공간정보 관련 협회 및 단체             NaN        NaN        NaN     181773.0
# 중간투입계                68653837.0  6191880.0  1371977.0  714825281.0
#
#                             최종수요계          총수요계
# 농림수산광업                 16607300.0    65496941.0
# 제조업                   762872604.0  1614698862.0
# SOC 산업                234976106.0   335638564.0
# 서비스업                  752623158.0  1230643850.0
# 공간정보 관련 제조업            59624834.0    92329586.0
# 공간정보 관련 도매업           116414163.0   247647642.0
# 공간정보 관련 출판 및 정보서비스업    41949909.0    73600196.0
# 공간정보 관련 기술서비스업          5953673.0    43914984.0
# 공간정보 관련 협회 및 단체       123671418.0   129591455.0
# 중간투입계                2114693165.0  3833562080.0

# %%
# 데이터 저장
year = int(input('실측자료의 기준연도를 입력해주세요 '))

# 총거래표 
for data in total_five_data:
    data.to_excel('{}년 총거래표(9)_2022_08_18.xlsx'.format(year))
    year += 1 

year -= 5
    
for data in total_twenty_data:
    data.to_excel('{}년 총거래표(20)_2022_08_18.xlsx'.format(year))
    year += 1 
    
year -= 5
    
for data in total_twentyfive_data:
    data.to_excel('{}년 총거래표(24)_2022_08_18.xlsx'.format(year))
    year += 1 
    
year -= 5

# 국산거래표 
for data in total_five_data_2:
    data.to_excel('{}년 국산거래표(9)_2022_08_18.xlsx'.format(year))
    year += 1 
    
year -= 5

for data in total_twenty_data_2:
    data.to_excel('{}년 국산거래표(20)_2022_08_18.xlsx'.format(year))
    year += 1 
    
year -= 5
for data in total_twentyfive_data_2:
    data.to_excel('{}년 국산거래표(24)_2022_08_18.xlsx'.format(year))
    year += 1 
    
print('저장 완료')
# Out:
# 실측자료의 기준연도를 입력해주세요 2015
# 저장 완료
