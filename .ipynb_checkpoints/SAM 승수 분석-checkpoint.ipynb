# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
def sam_analysis():
    print('=======================================')

    print()
    print('사회계정행렬 선택: ')
    print('1. 거시 사회계정행렬 \n 2. 거시 사회계정행렬(국산) \n 3. 미시 사회계정행렬(산업 세분화) \n 4. 미시 사회계정행렬(산업 세분화: 국산) \n 5. 미시 사회계정행렬(최종) \n 6. 미시 사회계정행렬(최종: 국산))')
    print()
    i = int(input('승수 분석을 진행할 SAM의 종류를 선택해주세요. : '))
    
    
    if i == 1:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='거시 사회계정행렬', skiprows=[0])
        print('데이터 불러오기 완료')
        print('========================================')
        un = 15
    elif i == 2:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='거시 사회계정행렬 (국산)',skiprows=[0])
        print('데이터 불러오기 완료')
        print('========================================')
        un = 15 
    elif i == 3:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='미시 사회계정행렬',skiprows=[0])

        un = 35
    elif i == 4:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='미시 사회계정행렬 (국산)',skiprows=[0])

        un = 35
        
    elif i == 5:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='미시 사회계정행렬 (최종)',skiprows=[0])

        un = 37
    elif i == 6:
        data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx', sheet_name='미시 사회계정행렬 (최종 국산)',skiprows=[0])

        un = 37
        
    else:
        print('번호를 잘못 입력했습니다. 함수를 다시 실행해주세요. ')
        print('========================================')
        
    data.drop('Unnamed: 0', axis=1, inplace=True)

    
    
    data.rename(columns={'Unnamed: 1':'구분', 'Unnamed: {}'.format(un):'총계'},inplace=True)
    data['구분'] = data['구분'].fillna('총계')
    print()
    data.set_index('구분', inplace=True)
    data.fillna(0, inplace=True)
    data.replace(' ', 0, inplace=True)
    data = data.astype('float')
    
    # 복사용 데이터 
    copy_data = data.copy()
    
    print('데이터 전처리 및 불러오기 완료')
    display(data)
    print('========================================')
    
    
    s11 = data.loc[:'정부', :'정부'].values

    s12 = data.loc[:'정부', '고정자본형성':'수입'].values
    
    s21 = data.loc['고정자본형성':'수입', :'정부'].values
    
    s22 = data.loc['고정자본형성':'수입', '고정자본형성':'수입'].values
    
    
    
    y1_r = data.loc['총계', :'정부'].values.reshape(1, -1)
    
    y2_r = data.loc['총계', '고정자본형성':'수입'].values.reshape(1, -1)
        

    
    y1_c = data.loc[:'정부', '총계'].values.reshape(-1, 1)
    y2_c = data.loc['고정자본형성':'수입', '총계'].values.reshape(-1, 1)
    
    
    # 투입계수 도출 
    
    h11 = s11 / y1_r
    h12 = s12 / y2_r
    h21 = s21 / y1_r
    h22 = s22 / y2_r
    
        
    # 승수행렬
    SAM_multiplier = np.linalg.inv(np.identity(h11.shape[0])-h11)   
    print()
    print('승수 행렬 : ')
    print(SAM_multiplier)
    
    print('어느 항목에 변화를 주겠습니까(번호 선택)? ')
    
    print('외생 변수 선택 : ')
    choise = int(input('1. 고정자본형성 \n 2. SCT 고정자본형성 \n 3. 간접세 \n 4. 법인세 \n 5. 소득세 \n 6. 관세 \n 7. 수출 \n 8. 수입'))

    print('===================================================')
    
    if choise == 1:
        target = '고정자본형성'
    elif choise == 2:
        target = 'SCT 고정자본형성'
    elif choise == 3:
        target = '간접세'
    elif choise == 4:
        target = '법인세'
    elif choise == 5:
        target = '소득세'
    elif choise == 6:
        target = '관세'
    elif choise == 7:
        target = '수출'
    elif choise == 8:
        target = '수입'

# %%
sam_analysis()
# Out:
# ...
#
# 사회계정행렬 선택:
# 1. 거시 사회계정행렬
#  2. 거시 사회계정행렬(국산)
#  3. 미시 사회계정행렬(산업 세분화)
#  4. 미시 사회계정행렬(산업 세분화: 국산)
#  5. 미시 사회계정행렬(최종)
#  6. 미시 사회계정행렬(최종: 국산))
#
# 승수 분석을 진행할 SAM의 종류를 선택해주세요. : 4
#
# 데이터 전처리 및 불러오기 완료
#                              농림어업             광업           제조업       도매 및 소매업  \
# 구분
# 농림어업                  4074.921000       4.310000  3.191858e+04      47.099710
# 광업                       0.560000       2.180000  3.603749e+03       0.000000
# 제조업                  16665.222090     649.679050  5.850183e+05   11139.515156
# 도매 및 소매업              1430.175359      34.859604  4.102672e+04    4383.313945
# 전기, 가스, 증기 및 수도사업      915.379000     108.589000  3.798951e+04    2401.291652
# 건설업                     81.793000      16.648000  1.208163e+03     187.527907
# 운수업                    737.414000     620.409000  4.644612e+04   12896.851382
# 숙박 및 음식점업              577.346000      96.834000  1.154636e+04    7444.006102
# ...

# %%
data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_1.xlsx',  sheet_name='거시 사회계정행렬',skiprows=[0])

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.rename(columns={'Unnamed: 1':'구분', 'Unnamed: 15':'총계'},inplace=True)

# %%
data['구분'] = data['구분'].fillna('총계')

# %%
data.set_index('구분', inplace=True)

# %%
data.fillna(0, inplace=True)
data.replace(' ', 0, inplace=True)

# %%
data = data.astype('float')

# %%
s11 = data.loc[:'정부', :'정부'].values

# %%
s12 = data.loc[:'정부', '고정자본형성':'수입'].values

# %%
s21 = data.loc['고정자본형성':'수입', :'정부'].values

# %%
s22 = data.loc['고정자본형성':'수입', '고정자본형성':'수입'].values

# %%
y1_r = data.loc['총계', :'정부'].values.reshape(1, 6)

# %%
y2_r = data.loc['총계', '고정자본형성':'수입'].values.reshape(1, 7)

# %%
y1_c = data.loc[:'정부', '총계'].values.reshape(6, 1)
y2_c = data.loc['고정자본형성':'수입', '총계'].values.reshape(7, 1)

# %%
h11 = s11 / y1_r
h12 = s12 / y2_r
h21 = s21 / y1_r
h22 = s22 / y2_r

# %%
h11
# Out:
# array([[0.48360538, 0.        , 0.        , 0.79627749, 0.        ,
#         0.71093363],
#        [0.17918774, 0.        , 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.16217238, 0.        , 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.31690608, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.68309392, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.17467497,
#         0.        ]])

# %%
# 승수행렬
SAM_multiplier = np.linalg.inv(np.identity(h11.shape[0])-h11)

# %%
SAM_multiplier
# Out:
# array([[3.13448916, 2.49592315, 1.05686622, 2.49592315, 0.38924809,
#         2.22841375],
#        [0.56166204, 1.44723884, 0.18937747, 0.44723884, 0.06974849,
#         0.39930443],
#        [0.50832756, 0.40476979, 1.17139451, 0.40476979, 0.06312529,
#         0.36138716],
#        [0.72275414, 1.57551285, 0.56059951, 1.57551285, 0.08975328,
#         0.51383022],
#        [0.34723547, 0.27649579, 0.80017247, 0.27649579, 1.0431205 ,
#         0.24686137],
#        [0.06065334, 0.04829689, 0.1397701 , 0.04829689, 0.18220704,
#         1.0431205 ]])

# %%
# result_vector = np.dot(np.dot(SAM_multiplier, h12), y2_r.transpose()).transpose()

# %%
# result_vector
# Out:
# array([[5097495.755,  913408.764,  826673.012, 1175386.464,  564695.312,
#          462297.98 ]])

# %%
# update_endogenous_metrix = h11 * result_vector

# %%
# update_endogenous_metrix

# %%
# update_endogenous_metrix
