# %%
import numpy as np
import pandas as pd

# %%
data_1 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_5.xlsx', sheet_name='미시 사회계정행렬', skiprows=[0])
data_2 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_5.xlsx', sheet_name='미시 사회계정행렬 (국산)', skiprows=[0])
data_3 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_5.xlsx', sheet_name='미시 사회계정행렬 (최종)', skiprows=[0])
data_4 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/sam 구축/sam_09_5.xlsx', sheet_name='미시 사회계정행렬 (최종 국산)', skiprows=[0])


total_data = [data_1, data_2, data_3, data_4]

# %%
total_result_data = []
i = 0
for data in total_data:

    data.drop('Unnamed: 0', axis=1, inplace=True)
    
    if i >= 2:
        data.rename(columns={'Unnamed: 1':'구분', 'Unnamed: 37':'총계'},inplace=True)
    else:
        data.rename(columns={'Unnamed: 1':'구분', 'Unnamed: 35':'총계'},inplace=True)
    data['구분'] = data['구분'].fillna('총계')
    data.set_index('구분', inplace=True)
    data.fillna(0, inplace=True)
    data.replace(' ', 0, inplace=True)
    data = data.astype('float')
    
    total_result_data.append(data)
    i += 1

# %%
# 자동으로 횟수 정해주는 RAS 
def Ras_1(total_data, metrix_num):
    
    result_metrix_list = []
    idx = 0
    for data in total_data:
        
        if idx >= 2:
            metrix_num = 35

        
        num = 0 

        
        standard_sum = data.loc['총계', :'수입'].values

        change_sum = data.loc[:'수입', '총계'].values

        input_coeff = data.loc[:'수입', :'수입'].values / change_sum
            

        metrix = np.identity(metrix_num)
        r = np.zeros(metrix_num)
        s = np.zeros(metrix_num)
        
        # 1차 잠정거래행렬
        m = np.dot(input_coeff , standard_sum * metrix)
        print('제{}차 잠정거래행렬 : '.format(num+1))
        print(m, end='\n\n')
        

        while True:
            i = 0
            if num % 2 == 0: 
                w = np.array([sum(m[i]) for i in range(metrix_num)])
                before_r = r 
                r = standard_sum / w 
                r = r.astype('float64')
                m = np.dot(r * metrix, m)
                num += 1 




            elif num % 2 != 0:
                z = np.array([sum(m[:, i]) for i in range(metrix_num)])
                before_s = s 
                s = standard_sum / z
                s = s.astype('float64')
                m = np.dot(m, s * metrix)
                num += 1 
            if num == 999:
                break



        

        print('------------------------------------------', end='\n\n')
        print('제{}차 잠정거래행렬 : '.format(num+1))
        print(m, end='\n\n')
        
        result_data = pd.DataFrame(data=m, columns=list(data.columns)[:-1], index=list(data.index)[:-1])
        result_metrix_list.append(result_data)
        print('행렬 조정 완료')
        print('==================================')
        idx += 1 
    return result_metrix_list

# %%
final_list = Ras_1(total_result_data, 33)
# Out:
# 제1차 잠정거래행렬 :
# [[4.47304300e+03 4.31976712e+00 3.90468951e+04 ... 0.00000000e+00
#   1.08094900e+03 0.00000000e+00]
#  [5.60000000e-01 2.18038720e+00 1.10842214e+05 ... 0.00000000e+00
#   1.12927000e+02 0.00000000e+00]
#  [1.77478754e+04 6.59560178e+02 8.39233604e+05 ... 0.00000000e+00
#   6.21764051e+05 0.00000000e+00]
#  ...
#  [5.43614000e+02 6.07045702e+03 1.68592529e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.15824170e+04 1.40646327e+05 4.27720128e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# ------------------------------------------
#
# 제1000차 잠정거래행렬 :
# [[4.47404606e+03 4.31906418e+00 3.90545343e+04 ... 0.00000000e+00
#   1.07965381e+03 0.00000000e+00]
#  [5.60084661e-01 2.17987315e+00 1.10855801e+05 ... 0.00000000e+00
#   1.12783452e+02 0.00000000e+00]
#  [1.77568904e+04 6.59639897e+02 8.39635879e+05 ... 0.00000000e+00
#   6.21195199e+05 0.00000000e+00]
#  ...
#  [5.43655095e+02 6.06856717e+03 1.68600452e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.15839023e+04 1.40609941e+05 4.27762742e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# 행렬 조정 완료
# ==================================
# 제1차 잠정거래행렬 :
# [[4.40168653e+03 1.00601128e+02 3.19185811e+04 ... 0.00000000e+00
#   1.08094900e+03 0.00000000e+00]
#  [6.04906072e-01 5.08840974e+01 3.60374900e+03 ... 0.00000000e+00
#   1.12927000e+02 0.00000000e+00]
#  [1.80015965e+04 1.51643725e+04 5.85018293e+05 ... 0.00000000e+00
#   6.21764051e+05 0.00000000e+00]
#  ...
#  [5.87206089e+02 1.41667373e+05 1.68592529e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.25112042e+04 3.28228920e+06 4.27720128e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# ------------------------------------------
#
# 제1000차 잠정거래행렬 :
# [[4.40156759e+03 4.60086419e+00 3.41694256e+04 ... 0.00000000e+00
#   1.14614368e+03 0.00000000e+00]
#  [1.35148474e+01 5.19940413e+01 8.61952975e+04 ... 0.00000000e+00
#   2.67526365e+03 0.00000000e+00]
#  [1.68893286e+04 6.50689958e+02 5.87593042e+05 ... 0.00000000e+00
#   6.18546804e+05 0.00000000e+00]
#  ...
#  [5.48774010e+02 6.05509724e+03 1.68673613e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.17221323e+04 1.40647703e+05 4.29015543e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# 행렬 조정 완료
# ==================================
# 제1차 잠정거래행렬 :
# [[4.47304300e+03 4.31976712e+00 3.90468951e+04 ... 0.00000000e+00
#   1.08094900e+03 0.00000000e+00]
#  [5.60000000e-01 2.18038720e+00 1.10842214e+05 ... 0.00000000e+00
#   1.12927000e+02 0.00000000e+00]
#  [1.77478754e+04 6.59560178e+02 8.39233604e+05 ... 0.00000000e+00
#   6.21764051e+05 0.00000000e+00]
#  ...
#  [5.43614000e+02 6.07045702e+03 1.68592529e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.15824170e+04 1.40646327e+05 4.27720128e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# ------------------------------------------
#
# 제1000차 잠정거래행렬 :
# [[4.47411084e+03 4.31904305e+00 3.90546456e+04 ... 0.00000000e+00
#   1.07964949e+03 0.00000000e+00]
#  [5.60090405e-01 2.17985328e+00 1.10855648e+05 ... 0.00000000e+00
#   1.12782524e+02 0.00000000e+00]
#  [1.77572110e+04 6.59639029e+02 8.39641274e+05 ... 0.00000000e+00
#   6.21194937e+05 0.00000000e+00]
#  ...
#  [5.43663116e+02 6.06853915e+03 1.68600979e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.15841339e+04 1.40610029e+05 4.27766320e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# 행렬 조정 완료
# ==================================
# 제1차 잠정거래행렬 :
# [[4.40168653e+03 1.00601128e+02 3.19185811e+04 ... 0.00000000e+00
#   1.08094900e+03 0.00000000e+00]
#  [6.04906072e-01 5.08840974e+01 3.60374900e+03 ... 0.00000000e+00
#   1.12927000e+02 0.00000000e+00]
#  [1.80015965e+04 1.51643725e+04 5.85018293e+05 ... 0.00000000e+00
#   6.21764051e+05 0.00000000e+00]
#  ...
#  [5.87206089e+02 1.41667373e+05 1.68592529e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.25112042e+04 3.28228920e+06 4.27720128e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# ------------------------------------------
#
# 제1000차 잠정거래행렬 :
# [[4.40171588e+03 4.59900924e+00 3.41685557e+04 ... 0.00000000e+00
#   1.14630480e+03 0.00000000e+00]
#  [1.35403389e+01 5.20693554e+01 8.63527704e+04 ... 0.00000000e+00
#   2.68059618e+03 0.00000000e+00]
#  [1.68961662e+04 6.50669020e+02 5.87796162e+05 ... 0.00000000e+00
#   6.18863361e+05 0.00000000e+00]
#  ...
#  [5.48853785e+02 6.05333191e+03 1.68688155e+04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 7.61603007e+05]
#  [1.17276050e+04 1.40651897e+05 4.29190452e+05 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
# 행렬 조정 완료
# ==================================

# %%
final_list[0].to_excel('미시 사회계정행렬 RAS 적용.xlsx')
final_list[1].to_excel('미시 사회계정행렬(국산) RAS 적용.xlsx')
final_list[2].to_excel('미시 사회계정행렬(최종) RAS 적용.xlsx')
final_list[3].to_excel('미시 사회계정행렬(최종 국산) RAS 적용.xlsx')
