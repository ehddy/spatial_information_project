# %%
import pandas as pd 
import numpy as np
import time 
import matplotlib.pyplot as plt 

                                                                                                                                                                                                                                                                                                                                                                                                                                                        
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')


# 맥 폰트 

plt.rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False


# # 윈도우 폰트 
# plt.rc('font', family='Malgun Gothic')

# plt.rcParams['axes.unicode_minus'] = False

# %%
# 2015년 기준 분류표 데이터 불러오기 
# 맥 
group_data =  pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_부문분류표.xlsx', usecols=[2, 3, 4, 5 ,6 ,7],skiprows=[0], sheet_name='상품분류표')

# %%
# 맥 

# 총 거래표(소분류 수준) 
small_data_2015 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2016 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2017 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2018 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2019 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])

total_small_data = [small_data_2015,small_data_2016, small_data_2017, small_data_2018, small_data_2019]



# 국산거래표(소분류 수준) 
small_data_2015_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2016_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2017_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2018_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
small_data_2019_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019_투입산출표_생산자가격_통합소분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])

total_small_domestic_data = [small_data_2015_domestic, small_data_2016_domestic, small_data_2017_domestic, small_data_2018_domestic, small_data_2019_domestic]

# %%
class Data_Preprocessing():
    
    
    def __init__(self, total_data, total_domestic_data, name_data, metrix_num, year):
        # 총 거래표 
        self.total_data = total_data
        
        # 국산 거래표 
        self.total_data_domestic = total_domestic_data
        
        # 행렬 차원 
        self.metrix_num = metrix_num
        
        # 분류표 데이터 
        self.name_data = name_data
        self.name_data = self.name_data.iloc[1:]
        self.name_data.reset_index(drop=True, inplace=True)
        self.name_data.rename(columns={'Unnamed: 3':'소분류명', 'Unnamed: 5':'중분류명', 'Unnamed: 7':'대분류명'}, inplace=True)
        
        # 산업연관표 기준연도 
        self.year = year 
        
        # 원하는 분류 
        self.special_industry_list = []

# %%
dp = Data_Preprocessing(total_small_data, total_small_domestic_data, group_data, 165, 2015)

# %%
dp.total_data
# Out:
# [     Unnamed: 0  Unnamed: 1  곡물 및 식량작물   채소 및 과실     기타작물  낙농 및 축우     기타 축산  \
#  0            11   곡물 및 식량작물     180950     39329    34323   180125    138368
#  1            12     채소 및 과실        445      1549      276      315      5170
#  2            19        기타작물          0    376829   223673    18385     28081
#  3            21     낙농 및 축우       6194     19384     5390    12099         0
#  4            29       기타 축산       1747     28885     5965        0    378204
#  ..          ...         ...        ...       ...      ...      ...       ...
#  167        9621        영업잉여    5801410   8397949  2045501  1055422   3429811
#  168        9622      고정자본소모     713808   1740931   311835   509062    736490
#  169        9630  생산세(보조금공제)    -415158    388446    90678    38152     64584
#  170        9690       부가가치계    6396618  11874782  2789346  1727069   4631216
#  171        9790        총투입계    8903046  17274156  3888227  7246880  12266879
#
#           임산물      수산물  농림어업 서비스  ...        수출       최종수요계        총수요계  \
#  0       2429        0     17094  ...   10996.0   1547385.0  13503721.0
#  1        104     1382       452  ...  310066.0  11083702.0  19432704.0
#  2        660     1402        22  ...  113118.0   1093325.0   7104470.0
#  3          0        0         0  ...       8.0    103404.0   7253530.0
#  4          0        0         0  ...    6619.0   1314667.0  12705075.0
#  ..       ...      ...       ...  ...       ...         ...         ...
#  167  1302044   507598     36707  ...       NaN         NaN         NaN
#  168   321855   455830     38582  ...       NaN         NaN         NaN
#  169   425103    15964      2275  ...       NaN         NaN         NaN
#  170  2395101  2840733    603478  ...       NaN         NaN         NaN
#  171  3399664  7260189   1132682  ...       NaN         NaN         NaN
#
#              총산출         수입  생산물세(수입)        수입계  도소매마진  화물운임        총공급계
#  0     8903046.0  4565995.0   34680.0  4600675.0    0.0   0.0  13503721.0
#  1    17274156.0  1867104.0  291444.0  2158548.0    0.0   0.0  19432704.0
#  2     3888227.0  3082085.0  134158.0  3216243.0    0.0   0.0   7104470.0
#  3     7246880.0     6650.0       0.0     6650.0    0.0   0.0   7253530.0
#  4    12266879.0   414626.0   23570.0   438196.0    0.0   0.0  12705075.0
#  ..          ...        ...       ...        ...    ...   ...         ...
#  167         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  168         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  169         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  170         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  171         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#
#  [172 rows x 184 columns],
#       Unnamed: 0  Unnamed: 1  곡물 및 식량작물   채소 및 과실     기타작물  낙농 및 축우     기타 축산  \
#  0            11   곡물 및 식량작물     135008     27019    23020   133257    110648
#  1            12     채소 및 과실        410      1230      212      309      4499
#  2            19        기타작물          0    405874   237262    17417     23684
#  3            21     낙농 및 축우      22502     67946    12853    15233         0
#  4            29       기타 축산       2084     28672     6500        0    345862
#  ..          ...         ...        ...       ...      ...      ...       ...
#  167        9621        영업잉여    5283068   8296498  2151489  1295676   3362875
#  168        9622      고정자본소모     660681   1785837   343142   574317    764310
#  169        9630  생산세(보조금공제)   -1009833    374652    92491    39132     60885
#  170        9690       부가가치계    5195897  11691016  2970309  2061106   4547014
#  171        9790        총투입계    7841080  16789345  4080525  7734423  12033526
#
#           임산물      수산물  농림어업 서비스  ...        수출       최종수요계        총수요계  \
#  0       1208        0      9712  ...    5065.0   1201360.0  11994039.0
#  1         78     1064       349  ...  342349.0  11027649.0  18973666.0
#  2        671     1135        18  ...  115811.0   1196672.0   7194679.0
#  3          0        0         0  ...       0.0    841880.0   7738908.0
#  4          0        0         0  ...    8024.0   1470895.0  12501887.0
#  ..       ...      ...       ...  ...       ...         ...         ...
#  167  1220100   589749     42451  ...       NaN         NaN         NaN
#  168   323908   507795     40449  ...       NaN         NaN         NaN
#  169   418169    13241      1749  ...       NaN         NaN         NaN
#  170  2302977  3021007    605660  ...       NaN         NaN         NaN
#  171  3226837  7477947   1124524  ...       NaN         NaN         NaN
#
#              총산출         수입  생산물세(수입)        수입계  도소매마진  화물운임        총공급계
#  0     7841080.0  4128308.0   24651.0  4152959.0    0.0   0.0  11994039.0
#  1    16789345.0  1861102.0  323219.0  2184321.0    0.0   0.0  18973666.0
#  2     4080525.0  2988487.0  125667.0  3114154.0    0.0   0.0   7194679.0
#  3     7734423.0     4485.0       0.0     4485.0    0.0   0.0   7738908.0
#  4    12033526.0   443401.0   24960.0   468361.0    0.0   0.0  12501887.0
#  ..          ...        ...       ...        ...    ...   ...         ...
#  167         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  168         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  169         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  170         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  171         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#
#  [172 rows x 184 columns],
#       Unnamed: 0  Unnamed: 1  곡물 및 식량작물   채소 및 과실     기타작물  낙농 및 축우     기타 축산  \
#  0            11   곡물 및 식량작물     156454     18118    23398   118217    135642
#  1            12     채소 및 과실        369       629      145      200      4497
#  2            19        기타작물          0    410500   240139    18969     23619
#  3            21     낙농 및 축우      15425     25981     7926     9818         0
#  4            29       기타 축산       2027     17975     5842        0    501711
#  ..          ...         ...        ...       ...      ...      ...       ...
#  167        9621        영업잉여    5747138   9031240  2139359  1502586   3672252
#  168        9622      고정자본소모     622594   1730608   335654   523756    829148
#  169        9630  생산세(보조금공제)   -1745487    387527   101608    37691     69565
#  170        9690       부가가치계    4898390  12479446  2979963  2253226   4993184
#  171        9790        총투입계    7626117  16492099  4011831  7153242  13202334
#
#           임산물      수산물  농림어업 서비스  ...        수출       최종수요계        총수요계  \
#  0       1779        0     10341  ...   17387.0    685879.0  11494650.0
#  1         73     1100       271  ...  353657.0  11136568.0  18720475.0
#  2        899     1366        16  ...  131590.0   1138384.0   7423082.0
#  3          0        0         0  ...       0.0    451981.0   7154361.0
#  4          0        0         0  ...    7469.0   1503535.0  13681726.0
#  ..       ...      ...       ...  ...       ...         ...         ...
#  167  1247608   775252     42855  ...       NaN         NaN         NaN
#  168   315539   594857     36903  ...       NaN         NaN         NaN
#  169   433938    15332      1659  ...       NaN         NaN         NaN
#  170  2346239  3467800    562182  ...       NaN         NaN         NaN
#  171  3322383  8620413   1039969  ...       NaN         NaN         NaN
#
#              총산출         수입  생산물세(수입)        수입계  도소매마진  화물운임        총공급계
#  0     7626117.0  3841974.0   26559.0  3868533.0    0.0   0.0  11494650.0
#  1    16492099.0  1899898.0  328478.0  2228376.0    0.0   0.0  18720475.0
#  2     4011831.0  3299541.0  111710.0  3411251.0    0.0   0.0   7423082.0
#  3     7153242.0     1119.0       0.0     1119.0    0.0   0.0   7154361.0
#  4    13202334.0   456205.0   23187.0   479392.0    0.0   0.0  13681726.0
#  ..          ...        ...       ...        ...    ...   ...         ...
#  167         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  168         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  169         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  170         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  171         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#
#  [172 rows x 184 columns],
#       Unnamed: 0  Unnamed: 1  곡물 및 식량작물   채소 및 과실     기타작물  낙농 및 축우     기타 축산  \
#  0            11   곡물 및 식량작물     208673     31122    34601   228186    205556
#  1            12     채소 및 과실        317       915      127      271      5173
#  2            19        기타작물          0    441652   227843    17840     22572
#  3            21     낙농 및 축우      19348     55182     9418    17502         0
#  4            29       기타 축산       1484     18544     4593        0    408630
#  ..          ...         ...        ...       ...      ...      ...       ...
#  167        9621        영업잉여    6540811   8257879  2023002  1334275   2148229
#  168        9622      고정자본소모     788844   1797321   320975   536620    719759
#  169        9630  생산세(보조금공제)    -754671    406798    99975    36684     57455
#  170        9690       부가가치계    6910378  11850238  2811581  2046702   3401798
#  171        9790        총투입계    9706019  16732940  3895666  7599069  11901637
#
#           임산물      수산물  농림어업 서비스  ...        수출       최종수요계        총수요계  \
#  0       2452        0     16016  ...    5960.0   -140667.0  13910331.0
#  1         65     1040       286  ...  377605.0  11221528.0  18919251.0
#  2        774     1318        17  ...  112549.0   1182796.0   6898312.0
#  3          0        0         0  ...       0.0    432871.0   7604689.0
#  4          0        0         0  ...    5846.0   1712188.0  12385472.0
#  ..       ...      ...       ...  ...       ...         ...         ...
#  167  1249341   234769      6171  ...       NaN         NaN         NaN
#  168   310724   570948     37842  ...       NaN         NaN         NaN
#  169   445619     9088       935  ...       NaN         NaN         NaN
#  170  2339130  3249186    573989  ...       NaN         NaN         NaN
#  171  3269727  8609756   1114967  ...       NaN         NaN         NaN
#
#              총산출         수입  생산물세(수입)        수입계  도소매마진  화물운임        총공급계
#  0     9706019.0  4179507.0   24805.0  4204312.0    0.0   0.0  13910331.0
#  1    16732940.0  1911126.0  275185.0  2186311.0    0.0   0.0  18919251.0
#  2     3895666.0  2892153.0  110493.0  3002646.0    0.0   0.0   6898312.0
#  3     7599069.0     5620.0       0.0     5620.0    0.0   0.0   7604689.0
#  4    11901637.0   460235.0   23600.0   483835.0    0.0   0.0  12385472.0
#  ..          ...        ...       ...        ...    ...   ...         ...
#  167         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  168         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  169         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  170         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  171         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#
#  [172 rows x 184 columns],
#       Unnamed: 0  Unnamed: 1  곡물 및 식량작물   채소 및 과실     기타작물  낙농 및 축우     기타 축산  \
#  0            11   곡물 및 식량작물     229627     43646    69329   300895    215056
#  1            12     채소 및 과실        219       711      110      197      3621
#  2            19        기타작물          0    421725   246303    15445     27590
#  3            21     낙농 및 축우      89924    398161   124797    64629         0
#  4            29       기타 축산       1519     18213     5789        0    638235
#  ..          ...         ...        ...       ...      ...      ...       ...
#  167        9621        영업잉여    6328998   7481667  1803040  1830095   1033038
#  168        9622      고정자본소모     817663   1797308   334018   589897    723717
#  169        9630  생산세(보조금공제)    -154922    447057   116456    41288     58897
#  170        9690       부가가치계    7360818  11381959  2679555  2629838   2568321
#  171        9790        총투입계    9940367  16524253  4031580  8254428  11775091
#
#           임산물      수산물  농림어업 서비스  ...        수출       최종수요계        총수요계  \
#  0       1959        0     37193  ...    5352.0   -144868.0  14578672.0
#  1         34      885       357  ...  455051.0  11336790.0  18574770.0
#  2        475     1160        21  ...  123146.0   1489744.0   7060051.0
#  3          0        0         0  ...       0.0    162717.0   8262229.0
#  4          0        0         0  ...   10793.0   1945276.0  12183602.0
#  ..       ...      ...       ...  ...       ...         ...         ...
#  167  1057772  -133442     39200  ...       NaN         NaN         NaN
#  168   269439   565293     45150  ...       NaN         NaN         NaN
#  169   474339     8226       928  ...       NaN         NaN         NaN
#  170  2134139  2958522    408993  ...       NaN         NaN         NaN
#  171  2785025  8367664   1254972  ...       NaN         NaN         NaN
#
#              총산출         수입  생산물세(수입)        수입계  도소매마진  화물운임        총공급계
#  0     9940367.0  4613141.0   25164.0  4638305.0    0.0   0.0  14578672.0
#  1    16524253.0  1800805.0  249712.0  2050517.0    0.0   0.0  18574770.0
#  2     4031580.0  2905627.0  122844.0  3028471.0    0.0   0.0   7060051.0
#  3     8254428.0     7800.0       1.0     7801.0    0.0   0.0   8262229.0
#  4    11775091.0   387053.0   21458.0   408511.0    0.0   0.0  12183602.0
#  ..          ...        ...       ...        ...    ...   ...         ...
#  167         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  168         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  169         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  170         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#  171         NaN        NaN       NaN        NaN    NaN   NaN         NaN
#
#  [172 rows x 184 columns]]
