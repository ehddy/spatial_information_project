# %%
import pandas as pd 
import numpy as np
import time 
import matplotlib.pyplot as plt 

                                                                                                                                                                                                                                                                                                                                                                                                                                                        
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')


# 맥 폰트 

# plt.rc('font', family='AppleGothic')

# plt.rcParams['axes.unicode_minus'] = False


# 윈도우 폰트 
plt.rc('font', family='Malgun Gothic')

plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 1) 25개 분류 데이터 불러오기

# %%
# test 용 데이터

# 윈도우 
# data = pd.read_excel('C:/Users/Innovation/Desktop/김동요/프로젝트/매크로/2019_투입산출표_생산자가격_통합대분류.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
# data.rename(columns={'Unnamed: 1':'상품분류'}, inplace=True)
# data.set_index('상품분류', inplace=True)
# data.drop('Unnamed: 0', axis=1, inplace=True)


# data_2 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/프로젝트/매크로/2019_투입산출표_생산자가격_통합대분류.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
# data_2.rename(columns={'Unnamed: 1':'상품분류'}, inplace=True)
# data_2.set_index('상품분류', inplace=True)
# data_2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# 맥 
data = pd.read_excel('/Users/dongyokim/Library/Mobile Documents/com~apple~CloudDocs/2022:1/비즈니스 애널리틱스/중간과제/산업연관표 데이터/2019년 연장표/투입산출표/생산자가격/투입산출표_생산자가격_통합대분류 오후 5.13.05.xlsx', sheet_name="A표_총거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
data.rename(columns={'Unnamed: 1':'상품분류'}, inplace=True)
data.set_index('상품분류', inplace=True)
data.drop('Unnamed: 0', axis=1, inplace=True)


data_2 = pd.read_excel('/Users/dongyokim/Library/Mobile Documents/com~apple~CloudDocs/2022:1/비즈니스 애널리틱스/중간과제/산업연관표 데이터/2019년 연장표/투입산출표/생산자가격/투입산출표_생산자가격_통합대분류 오후 5.13.05.xlsx', sheet_name="A표_국산거래표(생산자)", skiprows=[0, 1, 2, 3, 4])
data_2.rename(columns={'Unnamed: 1':'상품분류'}, inplace=True)
data_2.set_index('상품분류', inplace=True)
data_2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# 산업연관표 전처리 완료 데이터(분석데이터) 

# 윈도우

# 총 
# data_2015 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2015/총/2015년 총거래표(25).xlsx')
# data_2016 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2016/총/2016년 총거래표(25).xlsx')
# data_2017 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2017/총/2017년 총거래표(25).xlsx')
# data_2018 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2018/총/2018년 총거래표(25).xlsx')
# data_2019 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2019/총/2019년 총거래표(25).xlsx')

# total_data = [data_2015, data_2016, data_2017, data_2018, data_2019]

# # 국산 
# data_2015_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2015/국산/2015년 국산거래표(25).xlsx')
# data_2016_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2016/국산/2016년 국산거래표(25).xlsx')
# data_2017_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2017/국산/2017년 국산거래표(25).xlsx')
# data_2018_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2018/국산/2018년 국산거래표(25).xlsx')
# data_2019_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2019/국산/2019년 국산거래표(25).xlsx')

# total_data_domestic = [data_2015_domestic, data_2016_domestic, data_2017_domestic, data_2018_domestic, data_2019_domestic]

# %%
# 맥

# 총
data_2015 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015/총/2015년 총거래표(25).xlsx')
data_2016 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016/총/2016년 총거래표(25).xlsx')
data_2017 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017/총/2017년 총거래표(25).xlsx')
data_2018 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018/총/2018년 총거래표(25).xlsx')
data_2019 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019/총/2019년 총거래표(25).xlsx')

total_data = [data_2015, data_2016, data_2017, data_2018, data_2019]

# 국산 
data_2015_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015/국산/2015년 국산거래표(25).xlsx')
data_2016_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016/국산/2016년 국산거래표(25).xlsx')
data_2017_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017/국산/2017년 국산거래표(25).xlsx')
data_2018_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018/국산/2018년 국산거래표(25).xlsx')
data_2019_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019/국산/2019년 국산거래표(25).xlsx')

total_data_domestic = [data_2015_domestic, data_2016_domestic, data_2017_domestic, data_2018_domestic, data_2019_domestic]

# %% [markdown]
# ### 2) 5개 분류 데이터 불러오기

# %%
# 산업연관표 데이터 

# 윈도우

# 총 
# data_2015_5 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2015/총/2015년 총거래표(5).xlsx')
# data_2016_5 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2016/총/2016년 총거래표(5).xlsx')
# data_2017_5 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2017/총/2017년 총거래표(5).xlsx')
# data_2018_5 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2018/총/2018년 총거래표(5).xlsx')
# data_2019_5 = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2019/총/2019년 총거래표(5).xlsx')

# total_data_5 = [data_2015_5, data_2016_5, data_2017_5, data_2018_5, data_2019_5]

# # 국산 
# data_2015_5_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2015/국산/2015년 국산거래표(5).xlsx')
# data_2016_5_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2016/국산/2016년 국산거래표(5).xlsx')
# data_2017_5_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2017/국산/2017년 국산거래표(5).xlsx')
# data_2018_5_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2018/국산/2018년 국산거래표(5).xlsx')
# data_2019_5_domestic = pd.read_excel('C:/Users/Innovation/Desktop/김동요/jupyter/프로젝트/2019/국산/2019년 국산거래표(5).xlsx')


# total_data_5_domestic = [data_2015_5_domestic, data_2016_5_domestic, data_2017_5_domestic, data_2018_5_domestic, data_2019_5_domestic]

# %%
# 산업연관표 데이터 

# 맥용

# 총 
data_2015_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015/총/2015년 총거래표(5).xlsx')
data_2016_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016/총/2016년 총거래표(5).xlsx')
data_2017_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017/총/2017년 총거래표(5).xlsx')
data_2018_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018/총/2018년 총거래표(5).xlsx')
data_2019_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019/총/2019년 총거래표(5).xlsx')

total_data_5 = [data_2015_5, data_2016_5, data_2017_5, data_2018_5, data_2019_5]

# 국산 
data_2015_5_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2015/국산/2015년 국산거래표(5).xlsx')
data_2016_5_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2016/국산/2016년 국산거래표(5).xlsx')
data_2017_5_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2017/국산/2017년 국산거래표(5).xlsx')
data_2018_5_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2018/국산/2018년 국산거래표(5).xlsx')
data_2019_5_domestic = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/2019/국산/2019년 국산거래표(5).xlsx')


total_data_5_domestic = [data_2015_5_domestic, data_2016_5_domestic, data_2017_5_domestic, data_2018_5_domestic, data_2019_5_domestic]

# %% [markdown]
# ### 3)  고용표 불러오기

# %%
# 윈도우용

# %%
# 맥용

employ_data_25 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/고용표_최종(25).xlsx')
employ_data_5 = pd.read_excel('/Users/dongyokim/main/jupyter/2022:Summer/프로젝트/고용표_최종(5).xlsx')

# %% [markdown]
# ---

# %%
# 인덱스 설정 및 수정
for i in range(5):
    total_data[i].rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
    total_data[i].set_index('상품분류', inplace=True)
    
    total_data_domestic[i].rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
    total_data_domestic[i].set_index('상품분류', inplace=True)
    
    total_data_5[i].rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
    total_data_5[i].set_index('상품분류', inplace=True)
    
    total_data_5_domestic[i].rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
    total_data_5_domestic[i].set_index('상품분류', inplace=True)

    
employ_data_25.rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
employ_data_25.set_index('상품분류', inplace=True)
    
employ_data_5.rename(columns={'Unnamed: 0':'상품분류'}, inplace=True)
employ_data_5.set_index('상품분류', inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 공간정보산업의 산업구조

# %% [markdown]
# ### 1) 산업 규모 및 변화

# %% [markdown]
# - 2015~2019년 전체 산업 규모

# %%
# 연도
year = 2015
data_list_1 = []
data_list_2 = []

for data in total_data:
    # 중간수요
    middle_demand = data.loc['중간투입계', '중간수요계']

    # 최종수요 
    final_demand = data.loc['중간투입계', '최종수요계']

    # 총수요 
    total_demand = data.loc['중간투입계', '총수요계']
    
    
    # 중간 투입
    middle_input = data.loc['중간투입계', '중간수요계']
    
    # 부가가치
    added_value = data.loc['부가가치계', '중간수요계']
    
    # 수입계
    total_income = data.loc['중간투입계', '수입계']
    
    
    # 총공급 
    total_supply = data.loc['중간투입계', '총공급계']
    
    
    data_list_1.append([str(year), middle_demand, final_demand, total_demand])
    data_list_2.append([str(year), middle_input, added_value, total_income, total_supply])
    
    year += 1 


    
    
industry_scale_data_1 = pd.DataFrame(data=data_list_1, columns=['연도', '중간수요', '최종수요','총수요'])
    
industry_scale_data_2 = pd.DataFrame(data=data_list_2, columns=['연도', '중간투입', '부가가치','수입계', '총공급'])

industry_scale_data_1
# Out:
#      연도        중간수요          최종수요           총수요
# 0  2015  2196111412  2.261453e+09  4.457564e+09
# 1  2016  2205810695  2.327570e+09  4.533380e+09
# 2  2017  2356346978  2.504659e+09  4.861006e+09
# 3  2018  2463162840  2.611029e+09  5.074192e+09
# 4  2019  2465176361  2.632319e+09  5.097496e+09

# %%
industry_scale_data_2
# Out:
#      연도        중간투입        부가가치          수입계           총공급
# 0  2015  2196111412  1637450668  624002363.0  4.457564e+09
# 1  2016  2205810695  1719287094  608282683.0  4.533380e+09
# 2  2017  2356346978  1812094843  692564059.0  4.861006e+09
# 3  2018  2463162840  1873401237  737628012.0  5.074192e+09
# 4  2019  2465176361  1900740904  731578490.0  5.097496e+09

# %%
# 2015~2019년 전체 산업 규모 데이터 저장 
# industry_scale_data_1.to_excel('2015~2019 전산업 규모_1.xlsx')
# industry_scale_data_2.to_excel('2015~2019 전산업 규모_2.xlsx')

# %%
f, ax = plt.subplots(1,3)
f.suptitle('2015~2019년 전체 산업 규모', size=25)


# 격자 크기 설정 
f.set_size_inches((33, 10))

# 격자 여백 설정
plt.subplots_adjust(wspace=0.3, hspace=0.3)


ax[0].plot(industry_scale_data_1['연도'], industry_scale_data_1['중간수요'], color='r', marker='o')
ax[0].set_title('연도별 중간수요', fontsize=20)


ax[1].plot(industry_scale_data_1['연도'], industry_scale_data_1['최종수요'], marker='o')
ax[1].set_title('연도별 최종수요', fontsize=20)

ax[2].plot(industry_scale_data_1['연도'], industry_scale_data_1['총수요'], color='y', marker='o')
ax[2].set_title('연도별 총수요', fontsize=20)

plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
f, ax = plt.subplots(2,2)
f.suptitle('2015~2019년 전체 산업 규모', size=25)

# 격자 크기 설정 
f.set_size_inches((20, 20))

# 격자 여백 설정
plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax[0, 0].plot(industry_scale_data_2['연도'], industry_scale_data_2['중간투입'], color='r', marker='o')
ax[0, 0].set_title('연도별 중간투입', fontsize=20)

ax[0, 1].plot(industry_scale_data_2['연도'], industry_scale_data_2['부가가치'], marker='o')
ax[0, 1].set_title('연도별 부가가치', fontsize=20)

ax[1, 0].plot(industry_scale_data_2['연도'], industry_scale_data_2['수입계'], color='y', marker='o')
ax[1, 0].set_title('연도별 수입계', fontsize=20)

ax[1, 1].plot(industry_scale_data_2['연도'], industry_scale_data_2['총공급'], color='g', marker='o')
ax[1, 1].set_title('연도별 총공급', fontsize=20)


plt.show()

# %% [markdown]
# ---
# - 연도별 공간정보산업의 규모(25개 산업분류)

# %%
total_data_list_25= []

for data in total_data:
    
    
    df = pd.DataFrame(data=[], columns=['산업명', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급'])

    
    # 산업별 이름 
    industry_name_25 = list(data.index.values[:25])
    industry_name_25.append('총계')
    industry_name_25 = np.array(industry_name_25)    
    df['산업명'] = industry_name_25
    
    df.set_index('산업명', inplace=True)
    
    # 산업별 중간수요
    middle_demand_25 = data.loc[:'중간투입계', '중간수요계'].values
    df['중간수요'] = middle_demand_25

    # 산업별 최종수요
    final_demand_25 = data.loc[:'중간투입계', '최종수요계'].values
    df['최종수요'] = final_demand_25

    # 산업별 총수요계
    total_demand_25 =  data.loc[:'중간투입계', '총수요계'].values
    df['총수요'] = total_demand_25

    # 산업별 중간투입 
    middle_input_25 = data.loc['중간투입계', :'중간수요계'].values
    df['중간투입'] = middle_input_25

    # 산업별 부가가치
    added_value_25 = data.loc['부가가치계', :'중간수요계'].values
    df['부가가치']= added_value_25

    # 산업별 총투입계
    total_input_25 = data.loc['총투입계', :'중간수요계'].values
    df['총투입(=총산출)'] = total_input_25

    # 산업별 수입계
    total_income_25 = data.loc[:'중간투입계', '수입계'].values
    df['수입계'] = total_income_25

    # 산업별 총공급 
    total_supply_25 = data.loc[:'중간투입계', '총공급계'].values
    df['총공급'] = total_supply_25
    
    total_data_list_25.append(df)
    
# 연도별 산업구조 수치 
struc_data_2015 = total_data_list_25[0]
struc_data_2016 = total_data_list_25[1]
struc_data_2017 = total_data_list_25[2]
struc_data_2018 = total_data_list_25[3]
struc_data_2019 = total_data_list_25[4]

total_struc_data = [struc_data_2015, struc_data_2016, struc_data_2017, struc_data_2018, struc_data_2019]

total_data_list_25_per = []
for data in total_struc_data:
    df = data / data.loc['총계', :].values
    total_data_list_25_per.append(df)
    
    
# 연도별 산업구조 비중 
struc_data_2015_per = total_data_list_25_per[0]
struc_data_2016_per = total_data_list_25_per[1]
struc_data_2017_per = total_data_list_25_per[2]
struc_data_2018_per = total_data_list_25_per[3]
struc_data_2019_per = total_data_list_25_per[4]

total_struc_data_per = [struc_data_2015_per, struc_data_2016_per, struc_data_2017_per, struc_data_2018_per, struc_data_2019_per]

# %% [markdown]
# ---
# 연도별 공간정보산업의 규모(5개 산업분류)

# %%
total_data_list_5= []

for data in total_data_5:
    
    
    df = pd.DataFrame(data=[], columns=['산업명', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급'])

    
    # 산업별 이름 
    industry_name_5 = list(data.index.values[:5])
    industry_name_5.append('총계')
    industry_name_5 = np.array(industry_name_5)    
    df['산업명'] = industry_name_5
    
    df.set_index('산업명', inplace=True)
    
    # 산업별 중간수요
    middle_demand_5 = data.loc[:'중간투입계', '중간수요계'].values
    df['중간수요'] = middle_demand_5

    # 산업별 최종수요
    final_demand_5 = data.loc[:'중간투입계', '최종수요계'].values
    df['최종수요'] = final_demand_5

    # 산업별 총수요계
    total_demand_5 =  data.loc[:'중간투입계', '총수요계'].values
    df['총수요'] = total_demand_5

    # 산업별 중간투입 
    middle_input_5 = data.loc['중간투입계', :'중간수요계'].values
    df['중간투입'] = middle_input_5

    # 산업별 부가가치
    added_value_5 = data.loc['부가가치계', :'중간수요계'].values
    df['부가가치']= added_value_5

    # 산업별 총투입계
    total_input_5 = data.loc['총투입계', :'중간수요계'].values
    df['총투입(=총산출)'] = total_input_5

    # 산업별 수입계
    total_income_5 = data.loc[:'중간투입계', '수입계'].values
    df['수입계'] = total_income_5

    # 산업별 총공급 
    total_supply_5 = data.loc[:'중간투입계', '총공급계'].values
    df['총공급'] = total_supply_5
    
    total_data_list_5.append(df)

# 연도별 산업구조 수치 
struc_data_2015_5 = total_data_list_5[0]
struc_data_2016_5 = total_data_list_5[1]
struc_data_2017_5 = total_data_list_5[2]
struc_data_2018_5 = total_data_list_5[3]
struc_data_2019_5 = total_data_list_5[4]

total_struc_data_5 = [struc_data_2015_5, struc_data_2016_5, struc_data_2017_5, struc_data_2018_5, struc_data_2019_5]

# 연도별 산업구조 비중 


total_data_list_5_per = []
for data in total_struc_data_5:
    df = data / data.loc['총계', :].values
    total_data_list_5_per.append(df)
    
    
struc_data_2015_5_per = total_data_list_5_per[0]
struc_data_2016_5_per = total_data_list_5_per[1]
struc_data_2017_5_per = total_data_list_5_per[2]
struc_data_2018_5_per = total_data_list_5_per[3]
struc_data_2019_5_per = total_data_list_5_per[4]

total_struc_data_5_per = [struc_data_2015_5_per, struc_data_2016_5_per, struc_data_2017_5_per, struc_data_2018_5_per, struc_data_2019_5_per]

# %% [markdown]
# ---

# %% [markdown]
# - 2015년 공간정보산업의 규모(25개 산업분류)

# %%
# 2015년 기준 수치
struc_data_2015
# Out:
#                                 중간수요          최종수요           총수요  \
# 산업명
# 농림수산광업                     170481650  1.936998e+07  1.898516e+08
# 전기, 가스 수도사업                 89307901  2.284020e+07  1.121481e+08
# 건설업                         11441286  2.122351e+08  2.236763e+08
# 음식료품제조업                     83993423  6.434032e+07  1.483337e+08
# 코크스 및 석유정제품 제조업             82503850  5.551738e+07  1.380212e+08
# 화학물질 및 화학제품 제조업            217953323  9.037992e+07  3.083332e+08
# 공간정보외 기기 및 용품 제조업          106811393  1.525628e+08  2.593742e+08
# 전기장비 제조업                    67668021  4.647665e+07  1.141447e+08
# 운송장비 제조업                    88870410  1.989749e+08  2.878453e+08
# 제조업                        481177408  2.500307e+08  7.312081e+08
# 운수업                        100559870  6.421740e+07  1.647773e+08
# 숙박 및 음식점업                   55607847  8.987669e+07  1.454845e+08
# 공간정보외 정보통신업                 40962661  2.234666e+07  6.330932e+07
# 금융 및 보험업                    91667158  6.839461e+07  1.600618e+08
# 부동산업                        52048493  1.412339e+08  1.932823e+08
# 공간정보외 전문, 과학 및 기술관련 서비스업    80669166  8.214088e+07  1.628100e+08
# 사업 지원 서비스업                  77511471  1.268578e+07  9.019725e+07
# 의료, 보건업 및 사회복지서비스업           7148550  1.132478e+08  1.203964e+08
# 서비스업                        24770451  1.891531e+08  2.139236e+08
# 공간정보 관련 기술서비스업             0.011219  0.004862  0.010306
# 공간정보 관련 교육서비스업             0.029790  0.003165  0.025968
# 공간정보 관련 협회 및 단체            0.003387  0.000153  0.002923
# 총계                         1.000000  1.000000  1.000000

# %% [markdown]
# ---
# - 2019년 공간정보산업의 규모(5개 산업분류)

# %%
# 2019년 기준 수치
struc_data_2019_5
# Out:
#               중간수요          최종수요           총수요          중간투입          부가가치  \
# 산업명
# 농림수산광업   204555728  2.148086e+07  2.260366e+08  3.307367e+07  3.414616e+07
# 제조업     1211389464  9.408969e+08  2.152286e+09  1.227800e+09  5.059591e+08
# SOC 산업   111059087  2.854784e+08  3.965375e+08  2.349811e+08  1.613437e+08
# 서비스업     648884023  9.634183e+08  1.612302e+09  6.837202e+08  8.288735e+08
# 공간정보산업   289288059  4.210449e+08  7.103330e+08  2.856011e+08  3.704185e+08
# 총계      2465176361  2.632319e+09  5.097496e+09  2.465176e+09  1.900741e+09
#
#            총투입(=총산출)          수입계           총공급
# 산업명
# 농림수산광업  6.721983e+07  158816760.0  2.260366e+08
# 제조업     1.733759e+09  418526969.0  2.152286e+09
# SOC 산업  3.963248e+08     212633.0  3.965375e+08
# 서비스업    1.512594e+09   99708724.0  1.612302e+09
# 공간정보산업  6.560196e+08   54313404.0  7.103330e+08
# 총계      4.365917e+09  731578490.0  5.097496e+09

# %%
# 2019년 기준 비중
struc_data_2019_5_per
# Out:
#             중간수요      최종수요       총수요      중간투입      부가가치  총투입(=총산출)       수입계  \
# 산업명
# 농림수산광업  0.082978  0.008160  0.044343  0.013416  0.017965   0.015396  0.217088
# 제조업     0.491401  0.357440  0.422224  0.498058  0.266190   0.397112  0.572088
# SOC 산업  0.045051  0.108451  0.077791  0.095320  0.084885   0.090777  0.000291
# 서비스업    0.263220  0.365996  0.316293  0.277351  0.436079   0.346455  0.136293
# 공간정보산업  0.117350  0.159952  0.139349  0.115854  0.194881   0.150259  0.074241
# 총계      1.000000  1.000000  1.000000  1.000000  1.000000   1.000000  1.000000
#
#              총공급
# 산업명
# 농림수산광업  0.044343
# 제조업     0.422224
# SOC 산업  0.077791
# 서비스업    0.316293
# 공간정보산업  0.139349
# 총계      1.000000

# %% [markdown]
# ---

# %%
# 연도별  공간정보산업 규모 데이터 저장 (25)

# year = 2015
# for data, data_per in zip(total_struc_data, total_struc_data_per):
#     data.to_excel('{}년 공간정보산업 규모(25).xlsx'.format(year))
#     data_per.to_excel('{}년 공간정보산업 비중(25).xlsx'.format(year))
#     year += 1

# %%
# 연도별  공간정보산업 규모 데이터 저장 (5)

# year = 2015
# for data, data_per in zip(total_struc_data_5, total_struc_data_5_per):
#     data.to_excel('{}년 공간정보산업 규모(5).xlsx'.format(year))
#     data_per.to_excel('{}년 공간정보산업 비중(5).xlsx'.format(year))
#     year += 1

# %% [markdown]
# ---

# %% [markdown]
# - 연도별 공간정보산업의 규모 변화

# %%
# 수치
total_data_list_spac = []
spac_name = list(data_2019.index.values[19:25])

for i in spac_name:
    year = 2015
    df = pd.DataFrame(data=[], columns=['산업명', '연도', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급'])
    for data in total_struc_data:
        # 산업별 중간수요
        middle_demand = data.loc[i, '중간수요']
        # 산업별 최종수요
        final_demand = data.loc[i, '최종수요']
        # 산업별 총수요계
        total_demand =  data.loc[i, '총수요']    
        # 산업별 중간투입 
        middle_input = data.loc[i, '중간투입']
        # 산업별 부가가치
        added_value = data.loc[i, '부가가치']
        # 산업별 총투입계
        total_input = data.loc[i,'총투입(=총산출)']
        # 산업별 수입계
        total_income = data.loc[i, '수입계']
        # 산업별 총공급 
        total_supply = data.loc[i, '총공급']   
        df.loc[len(df)] = [i, year,middle_demand,final_demand, total_demand, middle_input, added_value, total_input, total_income, total_supply]
        year += 1
    total_data_list_spac.append(df)

    
year = 2015
i = '공간정보산업'
df = pd.DataFrame(data=[], columns=['산업명', '연도', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급']) 
for data in total_struc_data_5:
    # 산업별 중간수요
    middle_demand = data.loc[i, '중간수요']
    # 산업별 최종수요
    final_demand = data.loc[i, '최종수요']
    # 산업별 총수요계
    total_demand =  data.loc[i, '총수요']    
    # 산업별 중간투입 
    middle_input = data.loc[i, '중간투입']
    # 산업별 부가가치
    added_value = data.loc[i, '부가가치']
    # 산업별 총투입계
    total_input = data.loc[i, '총투입(=총산출)']
    # 산업별 수입계
    total_income = data.loc[i, '수입계']
    # 산업별 총공급 
    total_supply = data.loc[i, '총공급']   
    df.loc[len(df)] = [i, year,middle_demand,final_demand, total_demand, middle_input, added_value, total_input, total_income, total_supply]
    year += 1

total_data_list_spac.append(df)

# %%
# 비중 
total_data_list_spac_per = []
spac_name = list(data_2019.index.values[19:25])

for i in spac_name:
    year = 2015
    df = pd.DataFrame(data=[], columns=['산업명', '연도', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급'])
    for data in total_struc_data:
        # 산업별 중간수요
        middle_demand = data.loc[i, '중간수요'] / data.loc['총계', '중간수요']
        # 산업별 최종수요
        final_demand = data.loc[i, '최종수요'] / data.loc['총계', '최종수요']
        # 산업별 총수요계
        total_demand =  data.loc[i, '총수요'] / data.loc['총계', '총수요']
        # 산업별 중간투입 
        middle_input = data.loc[i, '중간투입'] / data.loc['총계', '중간투입']
        # 산업별 부가가치
        added_value = data.loc[i, '부가가치'] / data.loc['총계', '부가가치']
        # 산업별 총투입계
        total_input = data.loc[i,'총투입(=총산출)'] / data.loc['총계','총투입(=총산출)']
        # 산업별 수입계
        total_income = data.loc[i, '수입계'] / data.loc['총계', '수입계']
        # 산업별 총공급 
        total_supply = data.loc[i, '총공급'] / data.loc['총계', '총공급'] 
        df.loc[len(df)] = [i, year,middle_demand,final_demand, total_demand, middle_input, added_value, total_input, total_income, total_supply]
        year += 1
    total_data_list_spac_per.append(df)

    
year = 2015
i = '공간정보산업'
df = pd.DataFrame(data=[], columns=['산업명', '연도', '중간수요', '최종수요', '총수요', '중간투입', '부가가치', '총투입(=총산출)', '수입계', '총공급']) 
for data in total_struc_data_5:
    # 산업별 중간수요
    middle_demand = data.loc[i, '중간수요'] / data.loc['총계', '중간수요']
    # 산업별 최종수요
    final_demand = data.loc[i, '최종수요'] / data.loc['총계', '최종수요']
    # 산업별 총수요계
    total_demand =  data.loc[i, '총수요'] / data.loc['총계', '총수요'] 
    # 산업별 중간투입 
    middle_input = data.loc[i, '중간투입'] / data.loc['총계', '중간투입']
    # 산업별 부가가치
    added_value = data.loc[i, '부가가치'] / data.loc['총계', '부가가치']
    # 산업별 총투입계
    total_input = data.loc[i, '총투입(=총산출)'] / data.loc['총계', '총투입(=총산출)']
    # 산업별 수입계
    total_income = data.loc[i, '수입계'] / data.loc['총계', '수입계']
    # 산업별 총공급 
    total_supply = data.loc[i, '총공급'] / data.loc['총계', '총공급'] 
    df.loc[len(df)] = [i, year,middle_demand,final_demand, total_demand, middle_input, added_value, total_input, total_income, total_supply]
    year += 1

total_data_list_spac_per.append(df)

# %% [markdown]
# - 연도별 공간정보산업의 규모 변화(수치)

# %%
year_spac_data = pd.concat([total_data_list_spac[i] for i in range(7)], axis=0).reset_index(drop=True)
year_spac_data.set_index(['산업명', '연도'], inplace=True)

year_spac_data
# Out:
#                                중간수요         최종수요          총수요         중간투입  \
# 산업명                 연도
# 공간정보 관련 제조업         2015   48655926   72958862.0  121614788.0   68513150.0
#                     2016   48078909   76182909.0  124261818.0   66997200.0
#                     2017   48895640   77481300.0  126376940.0   65542099.0
#                     2018   52054935   69355254.0  121410189.0   60556209.0
#                     2019   51665146   71144998.0  122810144.0   59192741.0
# 공간정보 관련 도매업         2015  134624990  116414163.0  251039153.0  112267256.0
#                     2016  140412063  123082248.0  263494311.0  118251114.0
#                     2017  147484479  128279692.0  275764171.0  125109077.0
#                     2018  149326837  134119108.0  283445945.0  129392694.0
#                     2019  146686747  142694192.0  289380939.0  133476572.0
# 공간정보 관련 출판 및 정보서비스업 2015   33970561   44066752.0   78037313.0   28605784.0
#                     2016   35629209   45733298.0   81362507.0   27785134.0
#                     2017   37433909   51043001.0   88476910.0   29983832.0
#                     2018   39521232   53330264.0   92851496.0   30625886.0
#                     2019   38614595   59716304.0   98330899.0   30695774.0
# 공간정보 관련 기술서비스업      2015   41718003    5955834.0   47673837.0   14387271.0
#                     2016   41201521    5984816.0   47186337.0   14429807.0
#                     2017   41197982    5961866.0   47159848.0   14671765.0
#                     2018   43269698    5475081.0   48744779.0   15755005.0
#                     2019   45694336    6842344.0   52536680.0   16526636.0
# 공간정보 관련 교육서비스업      2015    2181713  116475679.0  118657392.0   35907649.0
#                     2016    2533051  117578624.0  120111675.0   35005027.0
#                     2017    1928961  121303335.0  123232296.0   35546453.0
#                     2018    2317659  124224140.0  126541799.0   35068310.0
#                     2019    2336251  130037878.0  132374129.0   37548607.0
# 공간정보 관련 협회 및 단체     2015    3805887    9556970.0   13362857.0    7677740.0
#                     2016    3987857   10105784.0   14093641.0    7734206.0
#                     2017   0.019786  0.008661  0.018201
#                     2018   0.019915  0.008799  0.018299
#                     2019   0.020750  0.010579  0.019290
# 공간정보 관련 기술서비스업      2015   0.011455  0.006024  0.010695
#                     2016   0.011134  0.005730  0.010409
#                     2017   0.010510  0.004838  0.009702
#                     2018   0.010655  0.003440  0.009606
#                     2019   0.011219  0.004862  0.010306
# 공간정보 관련 교육서비스업      2015   0.030345  0.003732  0.026619
#                     2016   0.030017  0.003767  0.026495
#                     2017   0.028988  0.003463  0.025351
#                     2018   0.028654  0.003092  0.024938
#                     2019   0.029790  0.003165  0.025968
# 공간정보 관련 협회 및 단체     2015   0.003460  0.000160  0.002998
#                     2016   0.003562  0.000183  0.003109
#                     2017   0.003459  0.000160  0.002989
#                     2018   0.003403  0.000144  0.002929
#                     2019   0.003387  0.000153  0.002923
# 공간정보산업              2015   0.153143  0.069393  0.141419
#                     2016   0.154147  0.074748  0.143493
#                     2017   0.150046  0.072314  0.138971
#                     2018   0.147329  0.066372  0.135560
#                     2019   0.150259  0.074241  0.139349

# %%
# 데이터 저장 
# year_spac_data.to_excel('연도별 공간정보산업 규모변화(수치).xlsx')

# year_spac_data_per.to_excel('연도별 공간정보산업 규모변화(비중).xlsx')

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 공간정보산업의 경제적 구조 및 변화
#
# ### 1) 경제적 구조

# %%
# 중간투입률, 부가가치율, 중간수요율, 최종수요율, 최종수요율, 수출율, 수입계수 
def eco_struc(data, metrix_num):
    
    df = pd.DataFrame(data=[], columns=['산업명', '중간투입률', '부가가치율', '중간수요율', '최종수요율', '수출율', '수입계수'])
    
    industry_name = data.index.values[:metrix_num]
 
    df['산업명'] = industry_name
    df.set_index('산업명', inplace=True)
    
    
    for i in industry_name:
        # 산업별 중간투입률 = 중간투입 / 총투입액(=총산출액) 
        middle_input_per = data.loc['중간투입계', i] / data.loc['총투입계', i]
        df.loc[i, '중간투입률'] = middle_input_per


        # 산업별 부가가치율 = 부가가치 / 총투입액(=총산출액)
        added_value_per = data.loc['부가가치계', i] / data.loc['총투입계', i] 
        df.loc[i, '부가가치율'] = added_value_per

        # 산업별 중간수요율 = 중간수요 / 총수요
        middle_demand_per = data.loc[i, '중간수요계'] / data.loc[i, '총수요계']
        df.loc[i, '중간수요율'] = middle_demand_per
        
        # 산업별 최종수요율 = 최종수요 / 총수요
        final_demand_per = data.loc[i, '최종수요계'] / data.loc[i, '총수요계']
        df.loc[i, '최종수요율'] = final_demand_per

        # 산업별 수출율 = 수출 / 총산출액(=총투입액)
        export_per =  data.loc[i, '수출'] / data.loc[i, '총산출']
        df.loc[i, '수출율'] = export_per
        
        # 산업별 수입계수 = 수입 / 총공급액 
        # 수입인지 수입계인지 확인 요망 
        total_income_per = data.loc[i, '수입계'] / data.loc[i, '총공급계']
        df.loc[i, '수입계수'] = total_income_per


    return df

# %%
# 연도별 경제적 구조 묶음 리스트 생성 
total_eco_struc_25 = []
total_eco_struc_5 = []
for data_25, data_5 in zip(total_data, total_data_5):
# Out:
#            중간투입률     부가가치율     중간수요율     최종수요율       수출율      수입계수
# 산업명
# 농림수산광업  0.492022  0.507978  0.904967  0.095033  0.017761  0.702615
# 제조업     0.708172  0.291828  0.562838  0.437162  0.342939  0.194457
# SOC 산업    0.5929    0.4071  0.280072  0.719928  0.003282  0.000536
# 서비스업    0.452018  0.547982  0.402458  0.597542  0.052771  0.061842
# 공간정보산업  0.435355  0.564645  0.407257  0.592743  0.129134  0.076462

# %% [markdown]
# ---

# %%
# 데이터 저장 
# year = 2015 
# for data25, data5 in zip(total_eco_struc_25, total_eco_struc_5):
#     data25.to_excel('{}년 공간정보산업 경제적 구조(25).xlsx'.format(year))
#     data5.to_excel('{}년 공간정보산업 경제적 구조(5).xlsx'.format(year))
    
#     year += 1

# %% [markdown]
# ---

# %% [markdown]
# ### 2) 경제적 구조의 변화(추세)

# %%
def eco_struc_change(total_data, metrix_num):
    df = pd.DataFrame(data=[], columns=['산업명', '연도', '중간투입률', '부가가치율', '중간수요율', '최종수요율', '수출율', '수입계수'])
    
    if metrix_num == 5:
        industry_name = [total_data[0].index.values[metrix_num-1]]
    
    elif metrix_num == 25:
        industry_name = total_data[0].index.values[metrix_num-6:metrix_num]
    
    
    for i in industry_name:
        year = 2015
        for data in total_data:

            
            # 산업별 중간투입률 = 중간투입 / 총투입액(=총산출액) 
            middle_input_per = data.loc[i, '중간투입률'] 


            # 산업별 부가가치율 = 부가가치 / 총투입액(=총산출액)
            added_value_per = data.loc[i, '부가가치율']

            # 산업별 중간수요율 = 중간수요 / 총수요
            middle_demand_per = data.loc[i, '중간수요율']

            # 산업별 최종수요율 = 최종수요 / 총수요
            final_demand_per = data.loc[i, '최종수요율']
            
            # 산업별 수출율 = 수출 / 총산출액(=총투입액)
            export_per =  data.loc[i, '수출율']

            # 산업별 수입계수 = 수입 / 총공급액 
            # 수입인지 수입계인지 확인 요망 
            total_income_per = data.loc[i, '수입계수']
            
            df.loc[len(df)] = [i, year,middle_input_per,added_value_per, middle_demand_per, final_demand_per, export_per, total_income_per]
    
            year += 1
        
    df.set_index(['산업명', '연도'], inplace=True)
    return df

# %%
# 25개 산업 기준 추이
eco_struc_change_data_25 = eco_struc_change(total_eco_struc_25, 25)

# 5개 산업 기준 추이
eco_struc_change_data_5 = eco_struc_change(total_eco_struc_5, 5)

# %% [markdown]
# ---
# - 공간정보산업 경제적 구조의 변화 (25개 산업분류)

# %%
eco_struc_change_data_25
# Out:
#                              중간투입률     부가가치율     중간수요율     최종수요율       수출율  \
# 산업명                 연도
# 공간정보 관련 제조업         2015  0.742050  0.257950  0.400082  0.599918  0.455399
#                     2016  0.725715  0.274285  0.386916  0.613084  0.482819
#                     2017  0.717401  0.282599  0.386903  0.613097  0.473312
#                     2018  0.693558  0.306442  0.428753  0.571247  0.391902
#                     2019  0.687789  0.312211  0.420691  0.579309  0.381861
# 공간정보 관련 도매업         2015  0.453335  0.546665  0.536271  0.463729  0.097450
#                     2016  0.454062  0.545938  0.532885  0.467115  0.106596
# eco_struc_25.to_excel("공간정보산업 경제적 구조의 변화(25).xlsx")


# eco_struc_5.to_excel("공간정보산업 경제적 구조의 변화(5).xlsx")

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 공간정보산업의 경제적 효과

# %% [markdown]
# ### 1) 생산유발효과

# %%
# 생산유발계수 행렬 
def input_prod_coeff(data, domestic_data, metrix_num):
    input_metrix = domestic_data.iloc[:, :metrix_num] / data.loc['총투입계', :data.index.values[metrix_num-1]]
    input_metrix = input_metrix.iloc[:metrix_num, :metrix_num]
    
    prod_induc_metrix = pd.DataFrame(data=np.linalg.inv(np.identity(metrix_num) - input_metrix), columns=[input_metrix.columns[i] for i in range(len(input_metrix.columns))], index=[input_metrix.columns[i] for i in range(len(input_metrix.columns))])
    
    
    
    prod_induc_metrix['행합'] = prod_induc_metrix.sum(axis=1)
    prod_induc_metrix.loc['열합', :] = prod_induc_metrix.sum(axis=0)


    prod_induc_metrix['감응도 계수'] = prod_induc_metrix['행합'] / prod_induc_metrix.loc[:data.index.values[metrix_num-1], '행합'].mean()
    prod_induc_metrix.loc['영향력 계수', :] = prod_induc_metrix.loc['열합', :] / prod_induc_metrix.loc['열합', :data.index.values[metrix_num-1]].mean()
    
    return prod_induc_metrix

# %%
total_prod_metrix_25 = []
for data, domestic_data in zip(total_data, total_data_domestic): 
    prod_metrix = input_prod_coeff(data, domestic_data, 25)
    total_prod_metrix_25.append(prod_metrix)

# %%
total_prod_metrix_5 = []
for data, domestic_data in zip(total_data_5, total_data_5_domestic): 
    prod_metrix = input_prod_coeff(data, domestic_data, 5)
    total_prod_metrix_5.append(prod_metrix)

# %%
# 생산유발계수 행렬 데이터 저장 
# year = 2015 
# for data25, data5 in zip(total_prod_metrix_25, total_prod_metrix_5):
#     data25.to_excel('{}년 생산유발계수 행렬(25).xlsx'.format(year))
#     data5.to_excel('{}년 생산유발계수 행렬(5).xlsx'.format(year))
#     year += 1

# %% [markdown]
# ---

# %%
# 산업별 생산유발효과 
def prod_effect_tabel(total_data, metrix_num):
    year = 2015
    index_names = total_data[0].index[:metrix_num]
    df = pd.DataFrame(data=[], index=index_names)
    for data in total_data:
        for name in index_names:
            df.loc[name, year] = data.loc['열합', name]
        year += 1 
    
    return df

# %%
prod_effect_25 = prod_effect_tabel(total_prod_metrix_25, 25)
prod_effect_5 = prod_effect_tabel(total_prod_metrix_5, 5)

# %% [markdown]
# - 산업별 생산유발계수(5개 산업분류)

# %%
prod_effect_5
# Out:
#             2015      2016      2017      2018      2019
# 농림수산광업  1.808468  1.811827  1.771872  1.809317  1.851788
# 제조업     1.971814  1.962613  1.919553  1.904425  1.922408
# SOC 산업  1.853513  1.862482  1.859862  1.850611  1.859399
# 서비스업    1.700862  1.708222  1.713684  1.718488  1.716499
# 공간정보산업  1.679004  1.658600  1.651466  1.647284  1.642849

# %% [markdown]
# - 산업별 생산유발계수(25개 산업)

# %%
prod_effect_25
# Out:
#                               2015      2016      2017      2018      2019
# 농림수산광업                    1.812953  1.821682  1.792192  1.837426  1.882572
# 전기, 가스 수도사업               1.483127  1.513550  1.522885  1.561865  1.582294
# 건설업                       1.990654  1.985822  1.989425  1.976847  1.967988
# 음식료품제조업                   2.162358  2.148519  2.165362  2.185369  2.200428
# 코크스 및 석유정제품 제조업           1.229940  1.207668  1.223920  1.225504  1.256370
# 화학물질 및 화학제품 제조업           1.846711  1.885930  1.882544  1.898725  1.890961
# 공간정보외 기기 및 용품 제조업         1.658049  1.600242  1.522717  1.503472  1.516183
# 전기장비 제조업                  2.038987  2.055387  2.040783  2.053826  2.070047
# 운송장비 제조업                  2.442721  2.416579  2.396924  2.433098  2.398252
# 제조업                       2.009145  2.015860  2.016269  2.022732  1.995245
# 운수업                       1.683235  1.725771  1.752627  1.776670  1.759614
# 숙박 및 음식점업                 2.143775  2.135759  2.146536  2.161995  2.156684
# 공간정보외 정보통신업               1.850668  1.841955  1.874912  1.898732  1.881225
# 금융 및 보험업                  1.641420  1.644632  1.630087  1.631882  1.637713
# 부동산업                      1.382278  1.394224  1.420398  1.430665  1.435681
# 공간정보외 전문, 과학 및 기술관련 서비스업  1.862321  1.875435  1.875917  1.890793  1.880323
# 사업 지원 서비스업                1.475403  1.481660  1.500526  1.501304  1.518982
# 의료, 보건업 및 사회복지서비스업        1.723675  1.721165  1.724543  1.736421  1.745702
# 서비스업                      1.582619  1.589654  1.590440  1.583763  1.568733
# 공간정보 관련 제조업               1.821565  1.736908  1.695505  1.706051  1.682995
# 공간정보 관련 도매업               1.727873  1.734685  1.741383  1.753454  1.758690
# 공간정보 관련 출판 및 정보서비스업       1.544545  1.497497  1.491410  1.475647  1.436025
# 공간정보 관련 기술서비스업            1.488436  1.502482  1.517687  1.533512  1.527303
# 공간정보 관련 교육서비스업            1.516935  1.502603  1.498693  1.480474  1.495551
# 공간정보 관련 협회 및 단체           2.036346  1.993767  1.990799  2.003408  2.004393

# %%
# 데이터 저장 

# prod_effect_5.to_excel('산업별 생산유발계수(5).xlsx')
# prod_effect_25.to_excel('산업별 생산유발계수(25).xlsx')

# %% [markdown]
# ---

# %%
# 산업별 영향력 계수 및 감응도 계수
# 영향력 계수
def backward_effect(data, index_name):
    backward_count = data.loc['영향력 계수', index_name]
    return backward_count

# 감응도 계수 
def forward_effect(data, index_name):
    forward_count = data.loc[index_name, '감응도 계수']
    return forward_count

def back_forward_table(total_data, metrix_num):
    year = 2015
    back_forward_name = ['영향력 계수', '감응도 계수']
    index_names = total_data[0].index[:metrix_num]
    df1 = pd.DataFrame(data=[], index=index_names)
    for data in total_data:
        for name in index_names:
            df1.loc[name, year] = backward_effect(data, name)
            df1.loc[name, '구분'] = '영향력 계수'
        year += 1
    
    year = 2015
    df2 = pd.DataFrame(data=[], index=index_names)
    for data in total_data:
        for name in index_names:
            df2.loc[name, year] = forward_effect(data, name)
            df2.loc[name, '구분'] = '감응도 계수'
        year += 1
        
    df = pd.concat([df1, df2], axis=0)
    
    df['산업명'] = df.index
    
    df.set_index(['구분', '산업명'], inplace=True)
    
    return df

# %%
back_forward_table_25 = back_forward_table(total_prod_metrix_25, 25)

#        사업 지원 서비스업                1.044891
#        의료, 보건업 및 사회복지서비스업        0.609582
#        서비스업                      0.749750
#        공간정보 관련 제조업               0.785714
#        공간정보 관련 도매업               1.401763
#        공간정보 관련 출판 및 정보서비스업       0.796811
#        공간정보 관련 기술서비스업            0.775938
#        공간정보 관련 교육서비스업            0.579319
#        공간정보 관련 협회 및 단체           0.590171

# %%
# 데이터 저장 
# back_forward_table_25.to_excel('산업별 영향력 계수 및 감응도 계수 테이블(25).xlsx')

# back_forward_table_5.to_excel('산업별 영향력 계수 및 감응도 계수 테이블(5).xlsx')

# %% [markdown]
# ---

# %% [markdown]
# ### 2) 부가가치유발효과

# %%
def added_value_coeff_metrix(data, domestic_data, metrix_num):
    
    # 생산유발계수 행렬 
    prod_coeff_metrix = input_prod_coeff(data, domestic_data, metrix_num).iloc[:metrix_num, :metrix_num].values

    idx_names = data.index[:metrix_num]
    # 부가가치 행렬 
    added_value_per = []
    for i in idx_names:
        added_value_per.append(data.loc['부가가치계', i] / data.loc['총투입계', i])
    
    #  부가가치율 대각행렬 
    added_value_metrix = (added_value_per * np.identity(metrix_num)).reshape([metrix_num, metrix_num])
    
    # 부가가치유발계수행렬 
    final_added_value_metrix = np.dot(added_value_metrix, prod_coeff_metrix)
    
    df = pd.DataFrame(data=final_added_value_metrix, index=idx_names, columns=idx_names)

    
    df['행합'] = df.sum(axis=1)
    df.loc['열합', :] = df.sum(axis=0)
    
    return df

# %%
# 부가가치유발계수 행렬 도출 
total_added_value_coeff_25 = []
for data, data_domestic in zip(total_data, total_data_domestic):
    total_added_value_coeff_25.append(added_value_coeff_metrix(data, data_domestic, 25))

    
total_added_value_coeff_5 = []
for data, data_domestic in zip(total_data_5, total_data_5_domestic):
    total_added_value_coeff_5.append(added_value_coeff_metrix(data, data_domestic, 5))

# %%
# 부가가치유발계수 행렬 데이터 저장 
# year = 2015 
# for data25, data5 in zip(total_added_value_coeff_25, total_added_value_coeff_5):
#     data25.to_excel('{}년 부가가치유발계수 행렬(25).xlsx'.format(year))
#     data5.to_excel('{}년 부가가치유발계수 행렬(5).xlsx'.format(year))
#     year += 1

# %% [markdown]
# ---

# %%
# 산업별 부가가치유발효과 
def added_value_coeff_result(total_data, metrix_num):
    year = 2015
    index_names = total_data[0].index[:metrix_num]
    df = pd.DataFrame(data=[], index=index_names)
    for data in total_data:
        for name in index_names:
            df.loc[name, year] = data.loc['열합', name]
        year += 1
    
    return df

# %%
# 테이블 생성 
added_value_coeff_table_25 = added_value_coeff_result(total_added_value_coeff_25, 25)
added_value_coeff_table_5 = added_value_coeff_result(total_added_value_coeff_5, 5)

# %% [markdown]
# - 산업별 부가가치유발계수(5개 산업분류)

# %%
added_value_coeff_table_5
# Out:
#             2015      2016      2017      2018      2019
# 상품분류
# 농림수산광업  0.854934  0.862844  0.861395  0.849000  0.848821
# 제조업     0.652185  0.674046  0.659671  0.646022  0.647735
# SOC 산업  0.744819  0.774598  0.756423  0.738158  0.748981
# 서비스업    0.867579  0.874706  0.870746  0.868109  0.868100
# 공간정보산업  0.856536  0.860925  0.857892  0.864164  0.864219

# %% [markdown]
# - 산업별 부가가치유발계수(25개 산업분류)

# %%
added_value_coeff_table_25
# Out:
#                               2015      2016      2017      2018      2019
# 상품분류
# 농림수산광업                    0.856255  0.865254  0.861038  0.844203  0.847563
# 전기, 가스 수도사업               0.594666  0.651026  0.588647  0.525587  0.553550
# 건설업                       0.810971  0.823237  0.815872  0.815649  0.820079
# 음식료품제조업                   0.741619  0.757142  0.749640  0.739550  0.745049
# 코크스 및 석유정제품 제조업           0.400847  0.450699  0.404488  0.340159  0.351964
# 화학물질 및 화학제품 제조업           0.603924  0.640636  0.617477  0.587241  0.593543
# 공간정보외 기기 및 용품 제조업         0.623540  0.635477  0.645421  0.669852  0.648983
# 전기장비 제조업                  0.686673  0.687266  0.676581  0.663113  0.672111
# 운송장비 제조업                  0.673093  0.692852  0.690555  0.681305  0.682258
# 제조업                       0.670202  0.689188  0.670869  0.659617  0.662820
# 운수업                       0.663122  0.691646  0.683371  0.654073  0.658848
# 숙박 및 음식점업                 0.818946  0.830686  0.822251  0.813769  0.817194
# 공간정보외 정보통신업               0.861550  0.866363  0.851957  0.845372  0.837406
# 금융 및 보험업                  0.925362  0.924528  0.918940  0.923932  0.921457
# 부동산업                      0.963515  0.964186  0.958847  0.957218  0.958095
# 공간정보외 전문, 과학 및 기술관련 서비스업  0.850841  0.859674  0.851499  0.849267  0.852677
# 사업 지원 서비스업                0.913218  0.917055  0.911081  0.914913  0.914252
# 의료, 보건업 및 사회복지서비스업        0.828243  0.836429  0.830143  0.823180  0.832227
# 서비스업                      0.901349  0.904512  0.895242  0.891989  0.893733
# 공간정보 관련 제조업               0.574694  0.569399  0.562985  0.587323  0.585768
# 공간정보 관련 도매업               0.886210  0.892132  0.882917  0.875622  0.875269
# 공간정보 관련 출판 및 정보서비스업       0.873680  0.880369  0.873810  0.874762  0.871734
# 공간정보 관련 기술서비스업            0.890584  0.897053  0.895145  0.892383  0.894772
# 공간정보 관련 교육서비스업            0.918926  0.928337  0.923717  0.922377  0.924516
# 공간정보 관련 협회 및 단체           0.866924  0.880100  0.874959  0.868558  0.873841

# %%
# 데이터 저장 
# added_value_coeff_table_25.to_excel('산업별 부가가치유발효과(25).xlsx')
# added_value_coeff_table_5.to_excel('산업별 부가가치유발효과(5).xlsx')

# %% [markdown]
# ---

# %% [markdown]
#  ### 3) 노동유발효과

# %%
# 산업별 총 산출액 
def total_input_prod_table(total_data, metrix_num):
    year = 2015
    index_names = total_data[0].index[:metrix_num]
    df = pd.DataFrame(data=[], index=index_names)
    for data in total_data:
        for name in index_names:
            df.loc[name, year] = data.loc['총투입계', name]
        year += 1
    
    return df

# %%
total_input_prod_table_25 = total_input_prod_table(total_data, 25)
total_input_prod_table_5 = total_input_prod_table(total_data_5, 5)

# %% [markdown]
# - 산업별 총 산출액(5개 산업분류)

# %%
total_input_prod_table_5
# Out:
#                 2015          2016          2017          2018          2019
# 상품분류
# 농림수산광업  6.549694e+07  6.483557e+07  6.620124e+07  6.734901e+07  6.721983e+07
# 화학물질 및 화학제품 제조업             434660.0    400718.1
# 공간정보외 기기 및 용품 제조업           238684.6    227376.6
# 전기장비 제조업                    238734.6    219090.0
# 운송장비 제조업                    447436.6    434110.8
# 제조업                        1947053.3   1684941.3
# 운수업                        1409388.3    816244.7
# 숙박 및 음식점업                  1944097.0   1080419.2
# 공간정보외 정보통신업                 182253.6    165063.1
# 금융 및 보험업                    660707.7    627573.9
# 부동산업                        579766.8    362044.5
# 공간정보외 전문, 과학 및 기술관련 서비스업   1085713.9   1020490.9
# 사업 지원 서비스업                 1146140.1   1061693.7
# 의료, 보건업 및 사회복지서비스업         1789726.5   1702895.3
# 서비스업                       2544336.5   1892576.8
# 공간정보 관련 제조업                 210492.6    174465.4
# 공간정보 관련 도매업                3351053.2   2023264.7
# 공간정보 관련 출판 및 정보서비스업         522401.8    469737.9
# 공간정보 관련 기술서비스업              426949.5    324544.7
# 공간정보 관련 교육서비스업             1532641.2   1205999.0
# 공간정보 관련 협회 및 단체             237185.2    223101.4
# 계                         24556585.0  18109054.7

# %% [markdown]
# ---

# %%
# 취업계수 및 고용계수 테이블 
def employ_coef(employ_data, total_input_data):
    df = pd.DataFrame(data=[], columns=['취업계수_2015', '고용계수_2015', '취업계수_2016', '고용계수_2016', '취업계수_2017', '고용계수_2017', '취업계수_2018', '고용계수_2018', '취업계수_2019', '고용계수_2019'], index=employ_data.index)
    data = total_input_data.copy()
    data.loc['계', :] = total_input_data.sum(axis=0)
    
    for i in range(2015, 2020):
        df['취업계수_{}'.format(i)] = employ_data['취업자수_{}'.format(i)] / data[i] * 1000
        df['고용계수_{}'.format(i)] = employ_data['피용자수_{}'.format(i)] / data[i] * 1000
    
    
    columns = [['2015년','2015년', '2016년','2016년',  '2017년','2017년', '2018년','2018년', '2019년', '2019년'], 
              ['취업계수', '고용계수', '취업계수', '고용계수', '취업계수', '고용계수', '취업계수', '고용계수', '취업계수', '고용계수']]
    
    
    df2 = pd.DataFrame(data=df.values, columns=columns, index=df.index)
    
    return df, df2

# %%
df_25, employ_coef_table_25 = employ_coef(employ_data_25, total_input_prod_table_25)
df_5, employ_coef_table_5 = employ_coef(employ_data_5, total_input_prod_table_5)

# %% [markdown]
# - 산업별 취업계수 및 고용계수(5개 산업 분류)

# %%
employ_coef_table_5
# Out:
#             2015년                2016년                2017년            \
#              취업계수      고용계수       취업계수      고용계수       취업계수      고용계수
# 상품분류
# 농림수산광업  18.924296  1.877100  18.209790  1.908107  18.003344  1.879601
# 제조업      2.384504  2.104076   2.387096  2.097449   2.214488  1.940156
# SOC 산업   5.513999  4.269302   5.287123  4.132135   5.122385  4.003400
# 서비스업     8.818413  6.758372   8.558391  6.571805   8.167540  6.236011
# 공간정보산업  10.781125  7.372153  10.432549  7.141062  10.145602  7.032982
# 계        6.292373  4.590654   6.185583  4.530956   5.884658  4.308850
#
#             2018년                2019년
#              취업계수      고용계수       취업계수      고용계수
# 상품분류
# 농림수산광업  18.412045  1.821667  19.190036  1.730427
# 제조업      2.102065  1.854403   2.105639  1.870081
# 금융 및 보험업                   3.894198   3.672366   3.785110   3.573114
# 부동산업                       2.606878   1.559489   2.437690   1.430658
# 공간정보외 전문, 과학 및 기술관련 서비스업   6.316047   5.933204   5.985688   5.611628
# 사업 지원 서비스업                14.050216  13.031893  12.355515  11.422033
# 의료, 보건업 및 사회복지서비스업        11.523576  10.907293  11.179958  10.563682
# 서비스업                      10.852583   8.083937  10.333570   7.775686
# 공간정보 관련 제조업                2.332848   1.924185   2.371075   1.956696
# 공간정보 관련 도매업               12.887033   7.652328  12.241652   7.342434
# 공간정보 관련 출판 및 정보서비스업        5.733233   5.030279   5.813845   5.138344
# 공간정보 관련 기술서비스업             9.025475   6.961220   8.822863   6.550640
# 공간정보 관련 교육서비스업            12.798348  10.120725  12.172786   9.526646
# 공간정보 관련 협회 및 단체           14.240041  13.493412  15.389772  14.834310
# 계                          5.884658   4.308850   5.648573   4.149537
#
#                               2019년
#                                취업계수       고용계수
# 상품분류
# 농림수산광업                    19.190036   1.730427
# 전기, 가스 수도사업                1.731133   1.552181
# 건설업                        6.481500   5.132835
# 음식료품제조업                    2.412948   1.919573
# 코크스 및 석유정제품 제조업            0.081775   0.081775
# 화학물질 및 화학제품 제조업            1.557705   1.436066
# 공간정보외 기기 및 용품 제조업          1.127501   1.074084
# 전기장비 제조업                   2.178843   1.999554
# 운송장비 제조업                   1.887540   1.831325
# 제조업                        3.132755   2.711024
# 운수업                        9.075849   5.256262
# 숙박 및 음식점업                 11.347724   6.306424
# 공간정보외 정보통신업                2.832405   2.565247
# 금융 및 보험업                   3.581080   3.401493
# 부동산업                       2.517840   1.572305
# 공간정보외 전문, 과학 및 기술관련 서비스업   5.957424   5.599539
# 사업 지원 서비스업                11.611431  10.755913
# 의료, 보건업 및 사회복지서비스업        10.691953  10.173218
# 서비스업                       9.841521   7.320508
# 공간정보 관련 제조업                2.445817   2.027199
# 공간정보 관련 도매업               11.735904   7.085785
# 공간정보 관련 출판 및 정보서비스업        5.766552   5.185220
# 공간정보 관련 기술서비스업             8.716821   6.626072
# 공간정보 관련 교육서비스업            11.784236   9.272736
# 공간정보 관련 협회 및 단체           16.038537  15.086186
# 계                          5.624611   4.147824

# %%
# 취업계수, 고용계수 데이터 저장
# employ_coef_table_25.to_excel('취업계수 및 고용계수(25).xlsx')
# employ_coef_table_5('취업계수 및 고용계수(5).xlsx')

# %% [markdown]
# ----

# %%
# 취업, 고용유발계수 행렬
def employ_coef_metrix(total_coef_table, total_prod_metrix, metrix_num):
    year = 2015
    
    total_c_coef_metrix = []
    total_p_coef_metrix = []
    for metrix in total_prod_metrix:
        m = metrix.iloc[:metrix_num, :metrix_num].values
        
        # 취업계수 
        c_coef = total_coef_table.drop('계')['취업계수_{}'.format(year)].values

        # 고용계수
        p_coef = total_coef_table.drop('계')['고용계수_{}'.format(year)].values
        
        # 취업유발계수 행렬
        c_coef_metrix = np.dot(c_coef * np.identity(metrix_num), m)
        
        # 고용유발계수 행렬
        p_coef_metrix = np.dot(p_coef * np.identity(metrix_num), m)

        df1 = pd.DataFrame(data=c_coef_metrix, columns=metrix.columns[:metrix_num], index=metrix.index[:metrix_num])
        df2 = pd.DataFrame(data=p_coef_metrix, columns=metrix.columns[:metrix_num], index=metrix.index[:metrix_num])
        
        df1['행합'] = df1.sum(axis=1)
        df1.loc['열합', :] = df1.sum(axis=0)
        
        df2['행합'] = df2.sum(axis=1)
        df2.loc['열합', :] = df2.sum(axis=0)
        
        total_c_coef_metrix.append(df1)
        total_p_coef_metrix.append(df2)
        year += 1 
    return total_c_coef_metrix, total_p_coef_metrix

# %%
# 취업, 고용유발계수 행렬
total_c_coef_metrix_25, total_p_coef_metrix_25 = employ_coef_metrix(df_25, total_prod_metrix_25, 25)

total_c_coef_metrix_5, total_p_coef_metrix_5 = employ_coef_metrix(df_5, total_prod_metrix_5, 5)

# %%
total_c_coef_metrix_5[0]
# Out:
#            농림수산광업       제조업     SOC 산업       서비스업     공간정보산업         행합
# 농림수산광업  20.018778  0.709762   0.280789   0.326391   0.155171  21.490891
# 제조업      1.123507  3.821903   1.134457   0.622664   0.520032   7.222564
# SOC 산업   0.194395  0.266969   5.889021   0.256641   0.192415   6.799440
# 서비스업     1.303272  1.542102   1.451159  11.174834   2.597217  18.068583
# 공간정보산업   1.039500  1.166639   1.405220   1.172191  12.110426  16.893976
# 열합      23.679452  7.507374  10.160646  13.552721  15.575260  70.475454

# %%
# # 취업유발계수 행렬 데이터 저장 
# year = 2015 
# for data25, data5 in zip(total_c_coef_metrix_25, total_c_coef_metrix_5):
#     data25.to_excel('{}년 취업유발계수 행렬(25).xlsx'.format(year))
#     data5.to_excel('{}년 취업유발계수 행렬(5).xlsx'.format(year))
#     year += 1
    
# # 고용유발계수 행렬 데이터 저장 
# year = 2015 
# for data25, data5 in zip(total_p_coef_metrix_25, total_p_coef_metrix_5):
#     data25.to_excel('{}년 고용유발계수 행렬(25).xlsx'.format(year))
#     data5.to_excel('{}년 고용유발계수 행렬(5).xlsx'.format(year))
#     year += 1

# %% [markdown]
# ---

# %%
# 노동, 고용유발계수 
def employ_coef_table(employ_coeff_metrix, metrix_num):
    year = 2015
    index_names = employ_coeff_metrix[0].index[:metrix_num]
    df = pd.DataFrame(data=[], index=index_names)
    
    for data in employ_coeff_metrix:
        for name in index_names:
            df.loc[name, year] = data.loc['열합', name]
        year += 1
    return df 

def total_employ_coef_table(c_metrix, p_metrix, metrix_num):
    total_c_table = employ_coef_table(c_metrix, metrix_num)
    total_p_table = employ_coef_table(p_metrix, metrix_num)
    
    df = pd.concat([total_c_table, total_p_table], axis=1)
    
    year_name = list(df.columns)
    
    multi = ['취업유발계수', '취업유발계수', '취업유발계수', '취업유발계수', '취업유발계수', '고용유발계수', '고용유발계수', '고용유발계수', '고용유발계수', '고용유발계수']
    
    multi_column = [multi, year_name]
    
    concat_df = pd.DataFrame(data=df.values, columns=multi_column, index=df.index)
    
    return concat_df

# %%
#연도별 취업,고용 유발계수 
total_employ_coef_table_5 = total_employ_coef_table(total_c_coef_metrix_5, total_p_coef_metrix_5, 5)
